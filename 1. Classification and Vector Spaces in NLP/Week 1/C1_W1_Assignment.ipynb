# %% [markdown]
# # Assignment 1: Logistic Regression
# Welcome to week one of this specialization. You will learn about logistic regression. Concretely, you will be implementing logistic regression for sentiment analysis on tweets. Given a tweet, you will decide if it has a positive sentiment or a negative one. Specifically you will:
#
# * Learn how to extract features for logistic regression given some text
# * Implement logistic regression from scratch
# * Apply logistic regression on a natural language processing task
# * Test using your logistic regression
# * Perform error analysis
#
# We will be using a data set of tweets. Hopefully you will get more than 99% accuracy.
# Run the cell below to load in the packages.

# %% [markdown]
# ## Import functions and data

# %%
# run this cell to import nltk
import nltk
from os import getcwd

# %% [markdown]
# ### Imported functions
#
# Download the data needed for this assignment. Check out the [documentation for the twitter_samples dataset](http://www.nltk.org/howto/twitter.html).
#
# * twitter_samples: if you're running this notebook on your local computer, you will need to download it using:
# ```Python
# nltk.download('twitter_samples')
# ```
#
# * stopwords: if you're running this notebook on your local computer, you will need to download it using:
# ```python
# nltk.download('stopwords')
# ```
#
# #### Import some helper functions that we provided in the utils.py file:
# * `process_tweet()`: cleans the text, tokenizes it into separate words, removes stopwords, and converts words to stems.
# * `build_freqs()`: this counts how often a word in the 'corpus' (the entire set of tweets) was associated with a positive label '1' or a negative label '0', then builds the `freqs` dictionary, where each key is a (word,label) tuple, and the value is the count of its frequency within the corpus of tweets.

# %%
# add folder, tmp2, from our local workspace containing pre-downloaded corpora files to nltk's data path
# this enables importing of these files without downloading it again when we refresh our workspace

# filePath = f"{getcwd()}/../tmp2/"
# nltk.data.path.append(filePath)

# %%
import numpy as np
import pandas as pd
from nltk.corpus import twitter_samples 

from utils import process_tweet, build_freqs

# %% [markdown]
# ### Prepare the data
# * The `twitter_samples` contains subsets of 5,000 positive tweets, 5,000 negative tweets, and the full set of 10,000 tweets.
#     * If you used all three datasets, we would introduce duplicates of the positive tweets and negative tweets.
#     * You will select just the five thousand positive tweets and five thousand negative tweets.

# %%
# select the set of positive and negative tweets
all_positive_tweets = twitter_samples.strings('positive_tweets.json')
all_negative_tweets = twitter_samples.strings('negative_tweets.json')

# %% [markdown]
# * Train test split: 20% will be in the test set, and 80% in the training set.

# %%
# split the data into two pieces, one for training and one for testing (validation set) 
test_pos = all_positive_tweets[4000:]
train_pos = all_positive_tweets[:4000]
test_neg = all_negative_tweets[4000:]
train_neg = all_negative_tweets[:4000]

train_x = train_pos + train_neg 
test_x = test_pos + test_neg

# %% [markdown]
# * Create the numpy array of positive labels and negative labels.

# %%
# combine positive and negative labels
train_y = np.append(np.ones((len(train_pos), 1)), np.zeros((len(train_neg), 1)), axis=0)
test_y = np.append(np.ones((len(test_pos), 1)), np.zeros((len(test_neg), 1)), axis=0)

# %%
# Print the shape train and test sets
print("train_y.shape = " + str(train_y.shape))
print("test_y.shape = " + str(test_y.shape))
# Out:
# train_y.shape = (8000, 1)
# test_y.shape = (2000, 1)

# %% [markdown]
# * Create the frequency dictionary using the imported `build_freqs()` function.
#     * We highly recommend that you open `utils.py` and read the `build_freqs()` function to understand what it is doing.
#     * To view the file directory, go to the menu and click File->Open.
#
# ```Python
#     for y,tweet in zip(ys, tweets):
#         for word in process_tweet(tweet):
#             pair = (word, y)
#             if pair in freqs:
#                 freqs[pair] += 1
#             else:
#                 freqs[pair] = 1
# ```
# * Notice how the outer for loop goes through each tweet, and the inner for loop steps through each word in a tweet.
# * The `freqs` dictionary is the frequency dictionary that's being built.
# * The key is the tuple (word, label), such as ("happy",1) or ("happy",0).  The value stored for each key is the count of how many times the word "happy" was associated with a positive label, or how many times "happy" was associated with a negative label.

# %%
# create frequency dictionary
freqs = build_freqs(train_x, train_y)

# check the output
print("type(freqs) = " + str(type(freqs)))
print("len(freqs) = " + str(len(freqs.keys())))
# Out:
# type(freqs) = <class 'dict'>
# len(freqs) = 11307

# %% [markdown]
# #### Expected output
# ```
# type(freqs) = <class 'dict'>
# len(freqs) = 11346
# ```

# %% [markdown]
# ### Process tweet
# The given function `process_tweet()` tokenizes the tweet into individual words, removes stop words and applies stemming.

# %%
# test the function below
print('This is an example of a positive tweet: \n', train_x[0])
print('\nThis is an example of the processed version of the tweet: \n', process_tweet(train_x[0]))
# Out:
# This is an example of a positive tweet:
#  #FollowFriday @France_Inte @PKuchly57 @Milipol_Paris for being top engaged members in my community this week :)
#
# This is an example of the processed version of the tweet:
#  ['followfriday', 'top', 'engag', 'member', 'commun', 'week', ':)']

# %% [markdown]
# #### Expected output
# ```
# This is an example of a positive tweet:
#  #FollowFriday @France_Inte @PKuchly57 @Milipol_Paris for being top engaged members in my community this week :)
#
# This is an example of the processes version:
#  ['followfriday', 'top', 'engag', 'member', 'commun', 'week', ':)']
# ```

# %% [markdown]
# # Part 1: Logistic regression
#
#
# ### Part 1.1: Sigmoid
# You will learn to use logistic regression for text classification.
# * The sigmoid function is defined as:
#
# $$ h(z) = \frac{1}{1+\exp^{-z}} \tag{1}$$
#
# It maps the input 'z' to a value that ranges between 0 and 1, and so it can be treated as a probability.
#
# <div style="width:image width px; font-size:100%; text-align:center;"><img src='../tmp2/sigmoid_plot.jpg' alt="alternate text" width="width" height="height" style="width:300px;height:200px;" /> Figure 1 </div>

# %% [markdown]
# #### Instructions: Implement the sigmoid function
# * You will want this function to work if z is a scalar as well as if it is an array.

# %% [markdown]
# <details>
# <summary>
#     <font size="3" color="darkgreen"><b>Hints</b></font>
# </summary>
# <p>
# <ul>
#     <li><a href="https://docs.scipy.org/doc/numpy/reference/generated/numpy.exp.html" > numpy.exp </a> </li>
#
# </ul>
# </p>

# %%
# UNQ_C1 (UNIQUE CELL IDENTIFIER, DO NOT EDIT)
def sigmoid(z): 
    '''
    Input:
        z: is the input (can be a scalar or an array)
    Output:
        h: the sigmoid of z
    '''
    
    ### START CODE HERE (REPLACE INSTANCES OF 'None' with your code) ###
    # calculate the sigmoid of z
    h = 1 / (1 + np.exp(-z))
    ### END CODE HERE ###
    
    return h

# %%
# Testing your function 
if (sigmoid(0) == 0.5):
    print('SUCCESS!')
else:
    print('Oops!')

if (sigmoid(4.92) == 0.9927537604041685):
    print('CORRECT!')
else:
    print('Oops again!')
# Out:
# SUCCESS!
# CORRECT!

# %% [markdown]
# ### Logistic regression: regression and a sigmoid
#
# Logistic regression takes a regular linear regression, and applies a sigmoid to the output of the linear regression.
#
# Regression:
# $$z = \theta_0 x_0 + \theta_1 x_1 + \theta_2 x_2 + ... \theta_N x_N$$
# Note that the $\theta$ values are "weights". If you took the Deep Learning Specialization, we referred to the weights with the `w` vector.  In this course, we're using a different variable $\theta$ to refer to the weights.
#
# Logistic regression
# $$ h(z) = \frac{1}{1+\exp^{-z}}$$
# $$z = \theta_0 x_0 + \theta_1 x_1 + \theta_2 x_2 + ... \theta_N x_N$$
# We will refer to 'z' as the 'logits'.

# %% [markdown]
# ### Part 1.2 Cost function and Gradient
#
# The cost function used for logistic regression is the average of the log loss across all training examples:
#
# $$J(\theta) = -\frac{1}{m} \sum_{i=1}^m y^{(i)}\log (h(z(\theta)^{(i)})) + (1-y^{(i)})\log (1-h(z(\theta)^{(i)}))\tag{5} $$
# * $m$ is the number of training examples
# * $y^{(i)}$ is the actual label of the i-th training example.
# * $h(z(\theta)^{(i)})$ is the model's prediction for the i-th training example.
#
# The loss function for a single training example is
# $$ Loss = -1 \times \left( y^{(i)}\log (h(z(\theta)^{(i)})) + (1-y^{(i)})\log (1-h(z(\theta)^{(i)})) \right)$$
#
# * All the $h$ values are between 0 and 1, so the logs will be negative. That is the reason for the factor of -1 applied to the sum of the two loss terms.
# * Note that when the model predicts 1 ($h(z(\theta)) = 1$) and the label $y$ is also 1, the loss for that training example is 0.
# * Similarly, when the model predicts 0 ($h(z(\theta)) = 0$) and the actual label is also 0, the loss for that training example is 0.
# * However, when the model prediction is close to 1 ($h(z(\theta)) = 0.9999$) and the label is 0, the second term of the log loss becomes a large negative number, which is then multiplied by the overall factor of -1 to convert it to a positive loss value. $-1 \times (1 - 0) \times log(1 - 0.9999) \approx 9.2$ The closer the model prediction gets to 1, the larger the loss.

# %%
# verify that when the model predicts close to 1, but the actual label is 0, the loss is a large positive value
-1 * (1 - 0) * np.log(1 - 0.9999) # loss is about 9.2
# Out:
# 9.210340371976294

# %% [markdown]
# * Likewise, if the model predicts close to 0 ($h(z) = 0.0001$) but the actual label is 1, the first term in the loss function becomes a large number: $-1 \times log(0.0001) \approx 9.2$.  The closer the prediction is to zero, the larger the loss.

# %%
# verify that when the model predicts close to 0 but the actual label is 1, the loss is a large positive value
-1 * np.log(0.0001) # loss is about 9.2
# Out:
# 9.210340371976182

# %% [markdown]
# #### Update the weights
#
# To update your weight vector $\theta$, you will apply gradient descent to iteratively improve your model's predictions.
# The gradient of the cost function $J$ with respect to one of the weights $\theta_j$ is:
#
# $$\nabla_{\theta_j}J(\theta) = \frac{1}{m} \sum_{i=1}^m(h^{(i)}-y^{(i)})x_j \tag{5}$$
# * 'i' is the index across all 'm' training examples.
# * 'j' is the index of the weight $\theta_j$, so $x_j$ is the feature associated with weight $\theta_j$
#
# * To update the weight $\theta_j$, we adjust it by subtracting a fraction of the gradient determined by $\alpha$:
# $$\theta_j = \theta_j - \alpha \times \nabla_{\theta_j}J(\theta) $$
# * The learning rate $\alpha$ is a value that we choose to control how big a single update will be.

# %% [markdown]
# ## Instructions: Implement gradient descent function
# * The number of iterations `num_iters` is the number of times that you'll use the entire training set.
# * For each iteration, you'll calculate the cost function using all training examples (there are `m` training examples), and for all features.
# * Instead of updating a single weight $\theta_i$ at a time, we can update all the weights in the column vector:
# $$\mathbf{\theta} = \begin{pmatrix}
# \theta_0
# \\
# \theta_1
# \\
# \theta_2
# \\
# \vdots
# \\
# \theta_n
# \end{pmatrix}$$
# * $\mathbf{\theta}$ has dimensions (n+1, 1), where 'n' is the number of features, and there is one more element for the bias term $\theta_0$ (note that the corresponding feature value $\mathbf{x_0}$ is 1).
# * The 'logits', 'z', are calculated by multiplying the feature matrix 'x' with the weight vector 'theta'.  $z = \mathbf{x}\mathbf{\theta}$
#     * $\mathbf{x}$ has dimensions (m, n+1)
#     * $\mathbf{\theta}$: has dimensions (n+1, 1)
#     * $\mathbf{z}$: has dimensions (m, 1)
# * The prediction 'h', is calculated by applying the sigmoid to each element in 'z': $h(z) = sigmoid(z)$, and has dimensions (m,1).
# * The cost function $J$ is calculated by taking the dot product of the vectors 'y' and 'log(h)'.  Since both 'y' and 'h' are column vectors (m,1), transpose the vector to the left, so that matrix multiplication of a row vector with column vector performs the dot product.
# $$J = \frac{-1}{m} \times \left(\mathbf{y}^T \cdot log(\mathbf{h}) + \mathbf{(1-y)}^T \cdot log(\mathbf{1-h}) \right)$$
# * The update of theta is also vectorized.  Because the dimensions of $\mathbf{x}$ are (m, n+1), and both $\mathbf{h}$ and $\mathbf{y}$ are (m, 1), we need to transpose the $\mathbf{x}$ and place it on the left in order to perform matrix multiplication, which then yields the (n+1, 1) answer we need:
# $$\mathbf{\theta} = \mathbf{\theta} - \frac{\alpha}{m} \times \left( \mathbf{x}^T \cdot \left( \mathbf{h-y} \right) \right)$$

# %% [markdown]
# <details>
# <summary>
#     <font size="3" color="darkgreen"><b>Hints</b></font>
# </summary>
# <p>
# <ul>
#     <li>use np.dot for matrix multiplication.</li>
#     <li>To ensure that the fraction -1/m is a decimal value, cast either the numerator or denominator (or both), like `float(1)`, or write `1.` for the float version of 1. </li>
# </ul>
# </p>

# %%
# UNQ_C2 (UNIQUE CELL IDENTIFIER, DO NOT EDIT)
def gradientDescent(x, y, theta, alpha, num_iters):
    '''
    Input:
        x: matrix of features which is (m,n+1)
        y: corresponding labels of the input matrix x, dimensions (m,1)
        theta: weight vector of dimension (n+1,1)
        alpha: learning rate
        num_iters: number of iterations you want to train your model for
    Output:
        J: the final cost
        theta: your final weight vector
    Hint: you might want to print the cost to make sure that it is going down.
    '''
    ### START CODE HERE (REPLACE INSTANCES OF 'None' with your code) ###
    # get 'm', the number of rows in matrix x
    m = x.shape[0]
    
    for i in range(0, num_iters):
        
        # get z, the dot product of x and theta
        z = np.dot(x, theta)
        
        # get the sigmoid of z
        h = sigmoid(z)
        
        # calculate the cost function
        J = -(float(1)/m) * (np.dot(y.T, np.log(h)) + np.dot((1-y).T, np.log(1-h)))
        print(f"Iteration {i}: Cost {J}")

        # update the weights theta
        theta = theta - (alpha/m) * np.dot(x.T, (h-y))
        
    ### END CODE HERE ###
    J = float(J)
    return J, theta

# %%
# Check the function
# Construct a synthetic test case using numpy PRNG functions
np.random.seed(1)
# X input is 10 x 3 with ones for the bias terms
tmp_X = np.append(np.ones((10, 1)), np.random.rand(10, 2) * 2000, axis=1)
# Y Labels are 10 x 1
tmp_Y = (np.random.rand(10, 1) > 0.35).astype(float)

# Apply gradient descent
tmp_J, tmp_theta = gradientDescent(tmp_X, tmp_Y, np.zeros((3, 1)), 1e-8, 700)
print(f"The cost after training is {tmp_J:.8f}.")
print(f"The resulting vector of weights is {[round(t, 8) for t in np.squeeze(tmp_theta)]}")
# Out:
# Iteration 0: Cost [[0.69314718]]
# Iteration 1: Cost [[0.69305407]]
# Iteration 2: Cost [[0.69296151]]
# Iteration 3: Cost [[0.6928695]]
# Iteration 4: Cost [[0.69277802]]
# Iteration 5: Cost [[0.69268708]]
# Iteration 6: Cost [[0.69259667]]
# Iteration 7: Cost [[0.69250679]]
# Iteration 8: Cost [[0.69241743]]
# Iteration 9: Cost [[0.69232859]]
# Iteration 10: Cost [[0.69224027]]
# Iteration 11: Cost [[0.69215246]]
# Iteration 12: Cost [[0.69206515]]
# Iteration 13: Cost [[0.69197836]]
# Iteration 14: Cost [[0.69189206]]
# Iteration 15: Cost [[0.69180626]]
# Iteration 16: Cost [[0.69172096]]
# Iteration 17: Cost [[0.69163614]]
# Iteration 18: Cost [[0.69155182]]
# Iteration 19: Cost [[0.69146797]]
# Iteration 20: Cost [[0.69138461]]
# Iteration 21: Cost [[0.69130172]]
# Iteration 22: Cost [[0.6912193]]
# Iteration 23: Cost [[0.69113736]]
# Iteration 24: Cost [[0.69105588]]
# Iteration 25: Cost [[0.69097486]]
# Iteration 26: Cost [[0.6908943]]
# Iteration 27: Cost [[0.6908142]]
# Iteration 28: Cost [[0.69073455]]
# Iteration 29: Cost [[0.69065535]]
# Iteration 30: Cost [[0.69057659]]
# Iteration 31: Cost [[0.69049828]]
# Iteration 32: Cost [[0.69042041]]
# Iteration 33: Cost [[0.69034297]]
# Iteration 34: Cost [[0.69026597]]
# Iteration 35: Cost [[0.6901894]]
# Iteration 36: Cost [[0.69011325]]
# Iteration 37: Cost [[0.69003753]]
# Iteration 38: Cost [[0.68996223]]
# Iteration 39: Cost [[0.68988734]]
# Iteration 40: Cost [[0.68981287]]
# Iteration 41: Cost [[0.68973881]]
# Iteration 42: Cost [[0.68966516]]
# Iteration 43: Cost [[0.68959192]]
# Iteration 44: Cost [[0.68951908]]
# Iteration 45: Cost [[0.68944664]]
# Iteration 46: Cost [[0.68937459]]
# Iteration 47: Cost [[0.68930294]]
# Iteration 48: Cost [[0.68923168]]
# Iteration 49: Cost [[0.68916081]]
# Iteration 50: Cost [[0.68909032]]
# Iteration 51: Cost [[0.68902022]]
# Iteration 52: Cost [[0.6889505]]
# Iteration 53: Cost [[0.68888115]]
# Iteration 54: Cost [[0.68881218]]
# Iteration 55: Cost [[0.68874358]]
# Iteration 56: Cost [[0.68867534]]
# Iteration 57: Cost [[0.68860748]]
# Iteration 58: Cost [[0.68853998]]
# Iteration 59: Cost [[0.68847284]]
# Iteration 60: Cost [[0.68840605]]
# Iteration 61: Cost [[0.68833963]]
# Iteration 62: Cost [[0.68827355]]
# Iteration 63: Cost [[0.68820783]]
# Iteration 64: Cost [[0.68814245]]
# Iteration 65: Cost [[0.68807742]]
# Iteration 66: Cost [[0.68801274]]
# Iteration 67: Cost [[0.68794839]]
# Iteration 68: Cost [[0.68788438]]
# Iteration 69: Cost [[0.68782071]]
# Iteration 70: Cost [[0.68775737]]
# Iteration 71: Cost [[0.68769436]]
# Iteration 72: Cost [[0.68763168]]
# Iteration 73: Cost [[0.68756933]]
# Iteration 74: Cost [[0.68750729]]
# Iteration 75: Cost [[0.68744558]]
# Iteration 76: Cost [[0.68738419]]
# Iteration 77: Cost [[0.68732312]]
# Iteration 78: Cost [[0.68726236]]
# Iteration 79: Cost [[0.68720191]]
# Iteration 80: Cost [[0.68714177]]
# Iteration 81: Cost [[0.68708194]]
# Iteration 82: Cost [[0.68702242]]
# Iteration 83: Cost [[0.6869632]]
# Iteration 84: Cost [[0.68690427]]
# Iteration 85: Cost [[0.68684565]]
# Iteration 86: Cost [[0.68678733]]
# Iteration 87: Cost [[0.6867293]]
# Iteration 88: Cost [[0.68667156]]
# Iteration 89: Cost [[0.68661411]]
# Iteration 90: Cost [[0.68655695]]
# Iteration 91: Cost [[0.68650007]]
# Iteration 92: Cost [[0.68644348]]
# Iteration 93: Cost [[0.68638717]]
# Iteration 94: Cost [[0.68633114]]
# Iteration 95: Cost [[0.68627539]]
# Iteration 96: Cost [[0.68621992]]
# Iteration 97: Cost [[0.68616471]]
# Iteration 98: Cost [[0.68610978]]
# Iteration 99: Cost [[0.68605512]]
# Iteration 100: Cost [[0.68600073]]
# Iteration 101: Cost [[0.68594661]]
# Iteration 102: Cost [[0.68589275]]
# Iteration 103: Cost [[0.68583915]]
# Iteration 104: Cost [[0.68578581]]
# Iteration 105: Cost [[0.68573273]]
# Iteration 106: Cost [[0.6856799]]
# Iteration 107: Cost [[0.68562733]]
# Iteration 108: Cost [[0.68557501]]
# Iteration 109: Cost [[0.68552295]]
# Iteration 110: Cost [[0.68547113]]
# Iteration 111: Cost [[0.68541956]]
# Iteration 112: Cost [[0.68536824]]
# Iteration 113: Cost [[0.68531716]]
# Iteration 114: Cost [[0.68526632]]
# Iteration 115: Cost [[0.68521573]]
# Iteration 116: Cost [[0.68516537]]
# Iteration 117: Cost [[0.68511525]]
# Iteration 118: Cost [[0.68506536]]
# Iteration 119: Cost [[0.68501571]]
# Iteration 120: Cost [[0.68496629]]
# Iteration 121: Cost [[0.6849171]]
# Iteration 122: Cost [[0.68486814]]
# Iteration 123: Cost [[0.6848194]]
# Iteration 124: Cost [[0.68477089]]
# Iteration 125: Cost [[0.68472261]]
# Iteration 126: Cost [[0.68467454]]
# Iteration 127: Cost [[0.6846267]]
# Iteration 128: Cost [[0.68457907]]
# Iteration 129: Cost [[0.68453167]]
# Iteration 130: Cost [[0.68448448]]
# Iteration 131: Cost [[0.6844375]]
# Iteration 132: Cost [[0.68439073]]
# Iteration 133: Cost [[0.68434418]]
# Iteration 134: Cost [[0.68429784]]
# Iteration 135: Cost [[0.6842517]]
# Iteration 136: Cost [[0.68420577]]
# Iteration 137: Cost [[0.68416005]]
# Iteration 138: Cost [[0.68411453]]
# Iteration 139: Cost [[0.68406921]]
# Iteration 140: Cost [[0.68402409]]
# Iteration 141: Cost [[0.68397918]]
# Iteration 142: Cost [[0.68393446]]
# Iteration 143: Cost [[0.68388993]]
# Iteration 144: Cost [[0.6838456]]
# Iteration 145: Cost [[0.68380147]]
# Iteration 146: Cost [[0.68375753]]
# Iteration 147: Cost [[0.68371378]]
# Iteration 148: Cost [[0.68367022]]
# Iteration 149: Cost [[0.68362684]]
# Iteration 150: Cost [[0.68358366]]
# Iteration 151: Cost [[0.68354066]]
# Iteration 152: Cost [[0.68349784]]
# Iteration 153: Cost [[0.68345521]]
# Iteration 154: Cost [[0.68341275]]
# Iteration 155: Cost [[0.68337048]]
# Iteration 156: Cost [[0.68332839]]
# Iteration 157: Cost [[0.68328647]]
# Iteration 158: Cost [[0.68324474]]
# Iteration 159: Cost [[0.68320317]]
# Iteration 160: Cost [[0.68316178]]
# Iteration 161: Cost [[0.68312057]]
# Iteration 162: Cost [[0.68307952]]
# Iteration 163: Cost [[0.68303865]]
# Iteration 164: Cost [[0.68299794]]
# Iteration 165: Cost [[0.68295741]]
# Iteration 166: Cost [[0.68291704]]
# Iteration 167: Cost [[0.68287683]]
# Iteration 168: Cost [[0.68283679]]
# Iteration 169: Cost [[0.68279691]]
# Iteration 170: Cost [[0.6827572]]
# Iteration 171: Cost [[0.68271764]]
# Iteration 172: Cost [[0.68267825]]
# Iteration 173: Cost [[0.68263901]]
# Iteration 174: Cost [[0.68259993]]
# Iteration 175: Cost [[0.68256101]]
# Iteration 176: Cost [[0.68252224]]
# Iteration 177: Cost [[0.68248363]]
# Iteration 178: Cost [[0.68244517]]
# Iteration 179: Cost [[0.68240686]]
# Iteration 180: Cost [[0.6823687]]
# Iteration 181: Cost [[0.6823307]]
# Iteration 182: Cost [[0.68229284]]
# Iteration 183: Cost [[0.68225513]]
# Iteration 184: Cost [[0.68221756]]
# Iteration 185: Cost [[0.68218015]]
# Iteration 186: Cost [[0.68214287]]
# Iteration 187: Cost [[0.68210574]]
# Iteration 188: Cost [[0.68206876]]
# Iteration 189: Cost [[0.68203191]]
# Iteration 190: Cost [[0.6819952]]
# Iteration 191: Cost [[0.68195864]]
# Iteration 192: Cost [[0.68192221]]
# Iteration 193: Cost [[0.68188592]]
# Iteration 194: Cost [[0.68184977]]
# Iteration 195: Cost [[0.68181375]]
# Iteration 196: Cost [[0.68177787]]
# Iteration 197: Cost [[0.68174212]]
# Iteration 198: Cost [[0.68170651]]
# Iteration 199: Cost [[0.68167102]]
# Iteration 200: Cost [[0.68163567]]
# Iteration 201: Cost [[0.68160045]]
# Iteration 202: Cost [[0.68156536]]
# Iteration 203: Cost [[0.68153039]]
# Iteration 204: Cost [[0.68149555]]
# Iteration 205: Cost [[0.68146084]]
# Iteration 206: Cost [[0.68142626]]
# Iteration 207: Cost [[0.6813918]]
# Iteration 208: Cost [[0.68135746]]
# Iteration 209: Cost [[0.68132325]]
# Iteration 210: Cost [[0.68128916]]
# Iteration 211: Cost [[0.68125519]]
# Iteration 212: Cost [[0.68122134]]
# Iteration 213: Cost [[0.68118761]]
# Iteration 214: Cost [[0.68115399]]
# Iteration 215: Cost [[0.6811205]]
# Iteration 216: Cost [[0.68108712]]
# Iteration 217: Cost [[0.68105386]]
# Iteration 218: Cost [[0.68102072]]
# Iteration 219: Cost [[0.68098769]]
# Iteration 220: Cost [[0.68095477]]
# Iteration 221: Cost [[0.68092197]]
# Iteration 222: Cost [[0.68088928]]
# Iteration 223: Cost [[0.6808567]]
# Iteration 224: Cost [[0.68082423]]
# Iteration 225: Cost [[0.68079187]]
# Iteration 226: Cost [[0.68075962]]
# Iteration 227: Cost [[0.68072748]]
# Iteration 228: Cost [[0.68069545]]
# Iteration 229: Cost [[0.68066352]]
# Iteration 230: Cost [[0.6806317]]
# Iteration 231: Cost [[0.68059999]]
# Iteration 232: Cost [[0.68056838]]
# Iteration 233: Cost [[0.68053687]]
# Iteration 234: Cost [[0.68050547]]
# Iteration 235: Cost [[0.68047417]]
# Iteration 236: Cost [[0.68044297]]
# Iteration 237: Cost [[0.68041187]]
# Iteration 238: Cost [[0.68038088]]
# Iteration 239: Cost [[0.68034998]]
# Iteration 240: Cost [[0.68031918]]
# Iteration 241: Cost [[0.68028848]]
# Iteration 242: Cost [[0.68025788]]
# Iteration 243: Cost [[0.68022738]]
# Iteration 244: Cost [[0.68019697]]
# Iteration 245: Cost [[0.68016666]]
# Iteration 246: Cost [[0.68013644]]
# Iteration 247: Cost [[0.68010632]]
# Iteration 248: Cost [[0.68007629]]
# Iteration 249: Cost [[0.68004635]]
# Iteration 250: Cost [[0.68001651]]
# Iteration 251: Cost [[0.67998676]]
# Iteration 252: Cost [[0.6799571]]
# Iteration 253: Cost [[0.67992753]]
# Iteration 254: Cost [[0.67989805]]
# Iteration 255: Cost [[0.67986866]]
# Iteration 256: Cost [[0.67983936]]
# Iteration 257: Cost [[0.67981014]]
# Iteration 258: Cost [[0.67978102]]
# Iteration 259: Cost [[0.67975198]]
# Iteration 260: Cost [[0.67972303]]
# Iteration 261: Cost [[0.67969416]]
# Iteration 262: Cost [[0.67966538]]
# Iteration 263: Cost [[0.67963668]]
# Iteration 264: Cost [[0.67960807]]
# Iteration 265: Cost [[0.67957954]]
# Iteration 266: Cost [[0.67955109]]
# Iteration 267: Cost [[0.67952272]]
# Iteration 268: Cost [[0.67949444]]
# Iteration 269: Cost [[0.67946624]]
# Iteration 270: Cost [[0.67943812]]
# Iteration 271: Cost [[0.67941008]]
# Iteration 272: Cost [[0.67938212]]
# Iteration 273: Cost [[0.67935423]]
# Iteration 274: Cost [[0.67932643]]
# Iteration 275: Cost [[0.6792987]]
# Iteration 276: Cost [[0.67927106]]
# Iteration 277: Cost [[0.67924348]]
# Iteration 278: Cost [[0.67921599]]
# Iteration 279: Cost [[0.67918857]]
# Iteration 280: Cost [[0.67916123]]
# Iteration 281: Cost [[0.67913396]]
# Iteration 282: Cost [[0.67910676]]
# Iteration 283: Cost [[0.67907964]]
# Iteration 284: Cost [[0.67905259]]
# Iteration 285: Cost [[0.67902562]]
# Iteration 286: Cost [[0.67899872]]
# Iteration 287: Cost [[0.67897189]]
# Iteration 288: Cost [[0.67894513]]
# Iteration 289: Cost [[0.67891844]]
# Iteration 290: Cost [[0.67889182]]
# Iteration 291: Cost [[0.67886527]]
# Iteration 292: Cost [[0.67883879]]
# Iteration 293: Cost [[0.67881238]]
# Iteration 294: Cost [[0.67878604]]
# Iteration 295: Cost [[0.67875977]]
# Iteration 296: Cost [[0.67873357]]
# Iteration 297: Cost [[0.67870743]]
# Iteration 298: Cost [[0.67868136]]
# Iteration 299: Cost [[0.67865535]]
# Iteration 300: Cost [[0.67862941]]
# Iteration 301: Cost [[0.67860354]]
# Iteration 302: Cost [[0.67857773]]
# Iteration 303: Cost [[0.67855199]]
# Iteration 304: Cost [[0.67852631]]
# Iteration 305: Cost [[0.67850069]]
# Iteration 306: Cost [[0.67847514]]
# Iteration 307: Cost [[0.67844965]]
# Iteration 308: Cost [[0.67842422]]
# Iteration 309: Cost [[0.67839885]]
# Iteration 310: Cost [[0.67837355]]
# Iteration 311: Cost [[0.67834831]]
# Iteration 312: Cost [[0.67832313]]
# Iteration 313: Cost [[0.678298]]
# Iteration 314: Cost [[0.67827294]]
# Iteration 315: Cost [[0.67824794]]
# Iteration 316: Cost [[0.678223]]
# Iteration 317: Cost [[0.67819812]]
# Iteration 318: Cost [[0.67817329]]
# Iteration 319: Cost [[0.67814852]]
# Iteration 320: Cost [[0.67812381]]
# Iteration 321: Cost [[0.67809916]]
# Iteration 322: Cost [[0.67807457]]
# Iteration 323: Cost [[0.67805003]]
# Iteration 324: Cost [[0.67802554]]
# Iteration 325: Cost [[0.67800112]]
# Iteration 326: Cost [[0.67797675]]
# Iteration 327: Cost [[0.67795243]]
# Iteration 328: Cost [[0.67792817]]
# Iteration 329: Cost [[0.67790396]]
# Iteration 330: Cost [[0.67787981]]
# Iteration 331: Cost [[0.67785571]]
# Iteration 332: Cost [[0.67783166]]
# Iteration 333: Cost [[0.67780767]]
# Iteration 334: Cost [[0.67778373]]
# Iteration 335: Cost [[0.67775984]]
# Iteration 336: Cost [[0.677736]]
# Iteration 337: Cost [[0.67771222]]
# Iteration 338: Cost [[0.67768848]]
# Iteration 339: Cost [[0.6776648]]
# Iteration 340: Cost [[0.67764117]]
# Iteration 341: Cost [[0.67761759]]
# Iteration 342: Cost [[0.67759406]]
# Iteration 343: Cost [[0.67757058]]
# Iteration 344: Cost [[0.67754714]]
# Iteration 345: Cost [[0.67752376]]
# Iteration 346: Cost [[0.67750042]]
# Iteration 347: Cost [[0.67747714]]
# Iteration 348: Cost [[0.6774539]]
# Iteration 349: Cost [[0.67743071]]
# Iteration 350: Cost [[0.67740756]]
# Iteration 351: Cost [[0.67738447]]
# Iteration 352: Cost [[0.67736142]]
# Iteration 353: Cost [[0.67733842]]
# Iteration 354: Cost [[0.67731546]]
# Iteration 355: Cost [[0.67729255]]
# Iteration 356: Cost [[0.67726968]]
# Iteration 357: Cost [[0.67724686]]
# Iteration 358: Cost [[0.67722409]]
# Iteration 359: Cost [[0.67720136]]
# Iteration 360: Cost [[0.67717868]]
# Iteration 361: Cost [[0.67715603]]
# Iteration 362: Cost [[0.67713344]]
# Iteration 363: Cost [[0.67711088]]
# Iteration 364: Cost [[0.67708837]]
# Iteration 365: Cost [[0.67706591]]
# Iteration 366: Cost [[0.67704348]]
# Iteration 367: Cost [[0.6770211]]
# Iteration 368: Cost [[0.67699876]]
# Iteration 369: Cost [[0.67697647]]
# Iteration 370: Cost [[0.67695421]]
# Iteration 371: Cost [[0.676932]]
# Iteration 372: Cost [[0.67690983]]
# Iteration 373: Cost [[0.67688769]]
# Iteration 374: Cost [[0.6768656]]
# Iteration 375: Cost [[0.67684355]]
# Iteration 376: Cost [[0.67682154]]
# Iteration 377: Cost [[0.67679957]]
# Iteration 378: Cost [[0.67677764]]
# Iteration 379: Cost [[0.67675575]]
# Iteration 380: Cost [[0.6767339]]
# Iteration 381: Cost [[0.67671209]]
# Iteration 382: Cost [[0.67669032]]
# Iteration 383: Cost [[0.67666858]]
# Iteration 384: Cost [[0.67664688]]
# Iteration 385: Cost [[0.67662522]]
# Iteration 386: Cost [[0.6766036]]
# Iteration 387: Cost [[0.67658202]]
# Iteration 388: Cost [[0.67656047]]
# Iteration 389: Cost [[0.67653897]]
# Iteration 390: Cost [[0.67651749]]
# Iteration 391: Cost [[0.67649606]]
# Iteration 392: Cost [[0.67647466]]
# Iteration 393: Cost [[0.6764533]]
# Iteration 394: Cost [[0.67643197]]
# Iteration 395: Cost [[0.67641068]]
# Iteration 396: Cost [[0.67638942]]
# Iteration 397: Cost [[0.6763682]]
# Iteration 398: Cost [[0.67634702]]
# Iteration 399: Cost [[0.67632587]]
# Iteration 400: Cost [[0.67630475]]
# Iteration 401: Cost [[0.67628367]]
# Iteration 402: Cost [[0.67626263]]
# Iteration 403: Cost [[0.67624161]]
# Iteration 404: Cost [[0.67622063]]
# Iteration 405: Cost [[0.67619969]]
# Iteration 406: Cost [[0.67617878]]
# Iteration 407: Cost [[0.6761579]]
# Iteration 408: Cost [[0.67613705]]
# Iteration 409: Cost [[0.67611624]]
# Iteration 410: Cost [[0.67609546]]
# Iteration 411: Cost [[0.67607472]]
# Iteration 412: Cost [[0.676054]]
# Iteration 413: Cost [[0.67603332]]
# Iteration 414: Cost [[0.67601267]]
# Iteration 415: Cost [[0.67599205]]
# Iteration 416: Cost [[0.67597146]]
# Iteration 417: Cost [[0.6759509]]
# Iteration 418: Cost [[0.67593038]]
# Iteration 419: Cost [[0.67590988]]
# Iteration 420: Cost [[0.67588942]]
# Iteration 421: Cost [[0.67586899]]
# Iteration 422: Cost [[0.67584858]]
# Iteration 423: Cost [[0.67582821]]
# Iteration 424: Cost [[0.67580787]]
# Iteration 425: Cost [[0.67578756]]
# Iteration 426: Cost [[0.67576727]]
# Iteration 427: Cost [[0.67574702]]
# Iteration 428: Cost [[0.6757268]]
# Iteration 429: Cost [[0.6757066]]
# Iteration 430: Cost [[0.67568643]]
# Iteration 431: Cost [[0.6756663]]
# Iteration 432: Cost [[0.67564619]]
# Iteration 433: Cost [[0.67562611]]
# Iteration 434: Cost [[0.67560606]]
# Iteration 435: Cost [[0.67558603]]
# Iteration 436: Cost [[0.67556604]]
# Iteration 437: Cost [[0.67554607]]
# Iteration 438: Cost [[0.67552613]]
# Iteration 439: Cost [[0.67550622]]
# Iteration 440: Cost [[0.67548633]]
# Iteration 441: Cost [[0.67546648]]
# Iteration 442: Cost [[0.67544665]]
# Iteration 443: Cost [[0.67542684]]
# Iteration 444: Cost [[0.67540707]]
# Iteration 445: Cost [[0.67538731]]
# Iteration 446: Cost [[0.67536759]]
# Iteration 447: Cost [[0.67534789]]
# Iteration 448: Cost [[0.67532822]]
# Iteration 449: Cost [[0.67530858]]
# Iteration 450: Cost [[0.67528896]]
# Iteration 451: Cost [[0.67526936]]
# Iteration 452: Cost [[0.67524979]]
# Iteration 453: Cost [[0.67523025]]
# Iteration 454: Cost [[0.67521073]]
# Iteration 455: Cost [[0.67519124]]
# Iteration 456: Cost [[0.67517177]]
# Iteration 457: Cost [[0.67515233]]
# Iteration 458: Cost [[0.67513291]]
# Iteration 459: Cost [[0.67511352]]
# Iteration 460: Cost [[0.67509415]]
# Iteration 461: Cost [[0.6750748]]
# Iteration 462: Cost [[0.67505548]]
# Iteration 463: Cost [[0.67503618]]
# Iteration 464: Cost [[0.67501691]]
# Iteration 465: Cost [[0.67499766]]
# Iteration 466: Cost [[0.67497844]]
# Iteration 467: Cost [[0.67495923]]
# Iteration 468: Cost [[0.67494005]]
# Iteration 469: Cost [[0.6749209]]
# Iteration 470: Cost [[0.67490177]]
# Iteration 471: Cost [[0.67488266]]
# Iteration 472: Cost [[0.67486357]]
# Iteration 473: Cost [[0.67484451]]
# Iteration 474: Cost [[0.67482546]]
# Iteration 475: Cost [[0.67480645]]
# Iteration 476: Cost [[0.67478745]]
# Iteration 477: Cost [[0.67476848]]
# Iteration 478: Cost [[0.67474952]]
# Iteration 479: Cost [[0.67473059]]
# Iteration 480: Cost [[0.67471168]]
# Iteration 481: Cost [[0.6746928]]
# Iteration 482: Cost [[0.67467393]]
# Iteration 483: Cost [[0.67465509]]
# Iteration 484: Cost [[0.67463627]]
# Iteration 485: Cost [[0.67461747]]
# Iteration 486: Cost [[0.67459869]]
# Iteration 487: Cost [[0.67457993]]
# Iteration 488: Cost [[0.67456119]]
# Iteration 489: Cost [[0.67454247]]
# Iteration 490: Cost [[0.67452378]]
# Iteration 491: Cost [[0.6745051]]
# Iteration 492: Cost [[0.67448645]]
# Iteration 493: Cost [[0.67446781]]
# Iteration 494: Cost [[0.6744492]]
# Iteration 495: Cost [[0.6744306]]
# Iteration 496: Cost [[0.67441203]]
# Iteration 497: Cost [[0.67439348]]
# Iteration 498: Cost [[0.67437494]]
# Iteration 499: Cost [[0.67435643]]
# Iteration 500: Cost [[0.67433793]]
# Iteration 501: Cost [[0.67431946]]
# Iteration 502: Cost [[0.674301]]
# Iteration 503: Cost [[0.67428257]]
# Iteration 504: Cost [[0.67426415]]
# Iteration 505: Cost [[0.67424575]]
# Iteration 506: Cost [[0.67422737]]
# Iteration 507: Cost [[0.67420901]]
# Iteration 508: Cost [[0.67419067]]
# Iteration 509: Cost [[0.67417235]]
# Iteration 510: Cost [[0.67415405]]
# Iteration 511: Cost [[0.67413576]]
# Iteration 512: Cost [[0.6741175]]
# Iteration 513: Cost [[0.67409925]]
# Iteration 514: Cost [[0.67408102]]
# Iteration 515: Cost [[0.67406281]]
# Iteration 516: Cost [[0.67404461]]
# Iteration 517: Cost [[0.67402644]]
# Iteration 518: Cost [[0.67400828]]
# Iteration 519: Cost [[0.67399014]]
# Iteration 520: Cost [[0.67397202]]
# Iteration 521: Cost [[0.67395391]]
# Iteration 522: Cost [[0.67393583]]
# Iteration 523: Cost [[0.67391776]]
# Iteration 524: Cost [[0.67389971]]
# Iteration 525: Cost [[0.67388167]]
# Iteration 526: Cost [[0.67386366]]
# Iteration 527: Cost [[0.67384566]]
# Iteration 528: Cost [[0.67382767]]
# Iteration 529: Cost [[0.67380971]]
# Iteration 530: Cost [[0.67379176]]
# Iteration 531: Cost [[0.67377383]]
# Iteration 532: Cost [[0.67375591]]
# Iteration 533: Cost [[0.67373801]]
# Iteration 534: Cost [[0.67372013]]
# Iteration 535: Cost [[0.67370226]]
# Iteration 536: Cost [[0.67368441]]
# Iteration 537: Cost [[0.67366658]]
# Iteration 538: Cost [[0.67364876]]
# Iteration 539: Cost [[0.67363096]]
# Iteration 540: Cost [[0.67361318]]
# Iteration 541: Cost [[0.67359541]]
# Iteration 542: Cost [[0.67357766]]
# Iteration 543: Cost [[0.67355992]]
# Iteration 544: Cost [[0.6735422]]
# Iteration 545: Cost [[0.6735245]]
# Iteration 546: Cost [[0.67350681]]
# Iteration 547: Cost [[0.67348913]]
# Iteration 548: Cost [[0.67347147]]
# Iteration 549: Cost [[0.67345383]]
# Iteration 550: Cost [[0.6734362]]
# Iteration 551: Cost [[0.67341859]]
# Iteration 552: Cost [[0.67340099]]
# Iteration 553: Cost [[0.67338341]]
# Iteration 554: Cost [[0.67336584]]
# Iteration 555: Cost [[0.67334829]]
# Iteration 556: Cost [[0.67333076]]
# Iteration 557: Cost [[0.67331323]]
# Iteration 558: Cost [[0.67329573]]
# Iteration 559: Cost [[0.67327823]]
# Iteration 560: Cost [[0.67326076]]
# Iteration 561: Cost [[0.67324329]]
# Iteration 562: Cost [[0.67322584]]
# Iteration 563: Cost [[0.67320841]]
# Iteration 564: Cost [[0.67319099]]
# Iteration 565: Cost [[0.67317358]]
# Iteration 566: Cost [[0.67315619]]
# Iteration 567: Cost [[0.67313882]]
# Iteration 568: Cost [[0.67312145]]
# Iteration 569: Cost [[0.6731041]]
# Iteration 570: Cost [[0.67308677]]
# Iteration 571: Cost [[0.67306945]]
# Iteration 572: Cost [[0.67305214]]
# Iteration 573: Cost [[0.67303485]]
# Iteration 574: Cost [[0.67301757]]
# Iteration 575: Cost [[0.6730003]]
# Iteration 576: Cost [[0.67298305]]
# Iteration 577: Cost [[0.67296581]]
# Iteration 578: Cost [[0.67294859]]
# Iteration 579: Cost [[0.67293138]]
# Iteration 580: Cost [[0.67291418]]
# Iteration 581: Cost [[0.67289699]]
# Iteration 582: Cost [[0.67287982]]
# Iteration 583: Cost [[0.67286266]]
# Iteration 584: Cost [[0.67284552]]
# Iteration 585: Cost [[0.67282839]]
# Iteration 586: Cost [[0.67281127]]
# Iteration 587: Cost [[0.67279416]]
# Iteration 588: Cost [[0.67277707]]
# Iteration 589: Cost [[0.67275999]]
# Iteration 590: Cost [[0.67274292]]
# Iteration 591: Cost [[0.67272587]]
# Iteration 592: Cost [[0.67270883]]
# Iteration 593: Cost [[0.6726918]]
# Iteration 594: Cost [[0.67267478]]
# Iteration 595: Cost [[0.67265778]]
# Iteration 596: Cost [[0.67264079]]
# Iteration 597: Cost [[0.67262381]]
# Iteration 598: Cost [[0.67260684]]
# Iteration 599: Cost [[0.67258989]]
# Iteration 600: Cost [[0.67257295]]
# Iteration 601: Cost [[0.67255602]]
# Iteration 602: Cost [[0.6725391]]
# Iteration 603: Cost [[0.6725222]]
# Iteration 604: Cost [[0.67250531]]
# Iteration 605: Cost [[0.67248843]]
# Iteration 606: Cost [[0.67247156]]
# Iteration 607: Cost [[0.6724547]]
# Iteration 608: Cost [[0.67243786]]
# Iteration 609: Cost [[0.67242102]]
# Iteration 610: Cost [[0.6724042]]
# Iteration 611: Cost [[0.6723874]]
# Iteration 612: Cost [[0.6723706]]
# Iteration 613: Cost [[0.67235381]]
# Iteration 614: Cost [[0.67233704]]
# Iteration 615: Cost [[0.67232028]]
# Iteration 616: Cost [[0.67230353]]
# Iteration 617: Cost [[0.67228679]]
# Iteration 618: Cost [[0.67227006]]
# Iteration 619: Cost [[0.67225334]]
# Iteration 620: Cost [[0.67223664]]
# Iteration 621: Cost [[0.67221995]]
# Iteration 622: Cost [[0.67220326]]
# Iteration 623: Cost [[0.67218659]]
# Iteration 624: Cost [[0.67216993]]
# Iteration 625: Cost [[0.67215329]]
# Iteration 626: Cost [[0.67213665]]
# Iteration 627: Cost [[0.67212002]]
# Iteration 628: Cost [[0.67210341]]
# Iteration 629: Cost [[0.6720868]]
# Iteration 630: Cost [[0.67207021]]
# Iteration 631: Cost [[0.67205363]]
# Iteration 632: Cost [[0.67203706]]
# Iteration 633: Cost [[0.6720205]]
# Iteration 634: Cost [[0.67200395]]
# Iteration 635: Cost [[0.67198741]]
# Iteration 636: Cost [[0.67197088]]
# Iteration 637: Cost [[0.67195436]]
# Iteration 638: Cost [[0.67193786]]
# Iteration 639: Cost [[0.67192136]]
# Iteration 640: Cost [[0.67190487]]
# Iteration 641: Cost [[0.6718884]]
# Iteration 642: Cost [[0.67187193]]
# Iteration 643: Cost [[0.67185548]]
# Iteration 644: Cost [[0.67183904]]
# Iteration 645: Cost [[0.6718226]]
# Iteration 646: Cost [[0.67180618]]
# Iteration 647: Cost [[0.67178977]]
# Iteration 648: Cost [[0.67177337]]
# Iteration 649: Cost [[0.67175697]]
# Iteration 650: Cost [[0.67174059]]
# Iteration 651: Cost [[0.67172422]]
# Iteration 652: Cost [[0.67170786]]
# Iteration 653: Cost [[0.67169151]]
# Iteration 654: Cost [[0.67167517]]
# Iteration 655: Cost [[0.67165883]]
# Iteration 656: Cost [[0.67164251]]
# Iteration 657: Cost [[0.6716262]]
# Iteration 658: Cost [[0.6716099]]
# Iteration 659: Cost [[0.67159361]]
# Iteration 660: Cost [[0.67157733]]
# Iteration 661: Cost [[0.67156106]]
# Iteration 662: Cost [[0.67154479]]
# Iteration 663: Cost [[0.67152854]]
# Iteration 664: Cost [[0.6715123]]
# Iteration 665: Cost [[0.67149607]]
# Iteration 666: Cost [[0.67147984]]
# Iteration 667: Cost [[0.67146363]]
# Iteration 668: Cost [[0.67144742]]
# Iteration 669: Cost [[0.67143123]]
# Iteration 670: Cost [[0.67141505]]
# Iteration 671: Cost [[0.67139887]]
# Iteration 672: Cost [[0.6713827]]
# Iteration 673: Cost [[0.67136655]]
# Iteration 674: Cost [[0.6713504]]
# Iteration 675: Cost [[0.67133426]]
# Iteration 676: Cost [[0.67131814]]
# Iteration 677: Cost [[0.67130202]]
# Iteration 678: Cost [[0.67128591]]
# Iteration 679: Cost [[0.67126981]]
# Iteration 680: Cost [[0.67125372]]
# Iteration 681: Cost [[0.67123763]]
# Iteration 682: Cost [[0.67122156]]
# Iteration 683: Cost [[0.6712055]]
# Iteration 684: Cost [[0.67118944]]
# Iteration 685: Cost [[0.6711734]]
# Iteration 686: Cost [[0.67115736]]
# Iteration 687: Cost [[0.67114133]]
# Iteration 688: Cost [[0.67112532]]
# Iteration 689: Cost [[0.67110931]]
# Iteration 690: Cost [[0.67109331]]
# Iteration 691: Cost [[0.67107732]]
# Iteration 692: Cost [[0.67106133]]
# Iteration 693: Cost [[0.67104536]]
# Iteration 694: Cost [[0.6710294]]
# Iteration 695: Cost [[0.67101344]]
# Iteration 696: Cost [[0.67099749]]
# Iteration 697: Cost [[0.67098155]]
# Iteration 698: Cost [[0.67096562]]
# Iteration 699: Cost [[0.6709497]]
# The cost after training is 0.67094970.
# The resulting vector of weights is [4.1e-07, 0.00035658, 7.309e-05]
# C:\Users\User\AppData\Local\Temp\ipykernel_9224\3262105165.py:35: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   J = float(J)

# %% [markdown]
# #### Expected output
# ```
# The cost after training is 0.67094970.
# The resulting vector of weights is [4.1e-07, 0.00035658, 7.309e-05]
# ```

# %% [markdown]
# ## Part 2: Extracting the features
#
# * Given a list of tweets, extract the features and store them in a matrix. You will extract two features.
#     * The first feature is the number of positive words in a tweet.
#     * The second feature is the number of negative words in a tweet.
# * Then train your logistic regression classifier on these features.
# * Test the classifier on a validation set.
#
# ### Instructions: Implement the extract_features function.
# * This function takes in a single tweet.
# * Process the tweet using the imported `process_tweet()` function and save the list of tweet words.
# * Loop through each word in the list of processed words
#     * For each word, check the `freqs` dictionary for the count when that word has a positive '1' label. (Check for the key (word, 1.0)
#     * Do the same for the count for when the word is associated with the negative label '0'. (Check for the key (word, 0.0).)

# %% [markdown]
# <details>
# <summary>
#     <font size="3" color="darkgreen"><b>Hints</b></font>
# </summary>
# <p>
# <ul>
#     <li>Make sure you handle cases when the (word, label) key is not found in the dictionary. </li>
#     <li> Search the web for hints about using the `.get()` method of a Python dictionary.  Here is an <a href="https://www.programiz.com/python-programming/methods/dictionary/get" > example </a> </li>
# </ul>
# </p>

# %%
# UNQ_C3 (UNIQUE CELL IDENTIFIER, DO NOT EDIT)
def extract_features(tweet, freqs):
    '''
    Input: 
        tweet: a list of words for one tweet
        freqs: a dictionary corresponding to the frequencies of each tuple (word, label)
    Output: 
        x: a feature vector of dimension (1,3)
    '''
    # process_tweet tokenizes, stems, and removes stopwords
    word_l = process_tweet(tweet)
    
    # 3 elements in the form of a 1 x 3 vector
    x = np.zeros((1, 3)) 
    
    #bias term is set to 1
    x[0,0] = 1 
    
    ### START CODE HERE (REPLACE INSTANCES OF 'None' with your code) ###
    
    # loop through each word in the list of words
    for word in word_l:
        
        # increment the word count for the positive label 1
        x[0,1] += freqs.get((word, 1.0), 0)
        
        # increment the word count for the negative label 0
        x[0,2] += freqs.get((word, 0.0), 0)
        
    ### END CODE HERE ###
    assert(x.shape == (1, 3))
    return x

# %%
# Check your function

# test 1
# test on training data
tmp1 = extract_features(train_x[0], freqs)
print(tmp1)
# Out:
# [[1.00e+00 3.02e+03 6.10e+01]]

# %% [markdown]
# #### Expected output
# ```
# [[1.00e+00 3.02e+03 6.10e+01]]
# ```

# %%
# test 2:
# check for when the words are not in the freqs dictionary
tmp2 = extract_features('blorb bleeeeb bloooob', freqs)
print(tmp2)
# Out:
# [[1. 0. 0.]]

# %% [markdown]
# #### Expected output
# ```
# [[1. 0. 0.]]
# ```

# %% [markdown]
# ## Part 3: Training Your Model
#
# To train the model:
# * Stack the features for all training examples into a matrix `X`.
# * Call `gradientDescent`, which you've implemented above.
#
# This section is given to you.  Please read it for understanding and run the cell.

# %%
# collect the features 'x' and stack them into a matrix 'X'
X = np.zeros((len(train_x), 3))
for i in range(len(train_x)):
    X[i, :]= extract_features(train_x[i], freqs)

# training labels corresponding to X
Y = train_y

# Apply gradient descent
J, theta = gradientDescent(X, Y, np.zeros((3, 1)), 1e-9, 1500)
print(f"The cost after training is {J:.8f}.")
print(f"The resulting vector of weights is {[round(t, 8) for t in np.squeeze(theta)]}")
# Out:
# Iteration 0: Cost [[0.69314718]]
# Iteration 1: Cost [[0.69207848]]
# Iteration 2: Cost [[0.69101305]]
# Iteration 3: Cost [[0.68995088]]
# Iteration 4: Cost [[0.68889195]]
# Iteration 5: Cost [[0.68783625]]
# Iteration 6: Cost [[0.68678378]]
# Iteration 7: Cost [[0.68573452]]
# Iteration 8: Cost [[0.68468846]]
# Iteration 9: Cost [[0.68364559]]
# Iteration 10: Cost [[0.6826059]]
# Iteration 11: Cost [[0.68156938]]
# Iteration 12: Cost [[0.68053602]]
# Iteration 13: Cost [[0.6795058]]
# Iteration 14: Cost [[0.67847872]]
# Iteration 15: Cost [[0.67745476]]
# Iteration 16: Cost [[0.67643391]]
# Iteration 17: Cost [[0.67541616]]
# Iteration 18: Cost [[0.67440151]]
# Iteration 19: Cost [[0.67338993]]
# Iteration 20: Cost [[0.67238143]]
# Iteration 21: Cost [[0.67137598]]
# Iteration 22: Cost [[0.67037358]]
# Iteration 23: Cost [[0.66937422]]
# Iteration 24: Cost [[0.66837788]]
# Iteration 25: Cost [[0.66738455]]
# Iteration 26: Cost [[0.66639423]]
# Iteration 27: Cost [[0.6654069]]
# Iteration 28: Cost [[0.66442256]]
# Iteration 29: Cost [[0.66344118]]
# Iteration 30: Cost [[0.66246276]]
# Iteration 31: Cost [[0.6614873]]
# Iteration 32: Cost [[0.66051477]]
# Iteration 33: Cost [[0.65954517]]
# Iteration 34: Cost [[0.65857849]]
# Iteration 35: Cost [[0.65761471]]
# Iteration 36: Cost [[0.65665383]]
# Iteration 37: Cost [[0.65569584]]
# Iteration 38: Cost [[0.65474072]]
# Iteration 39: Cost [[0.65378846]]
# Iteration 40: Cost [[0.65283906]]
# Iteration 41: Cost [[0.65189249]]
# Iteration 42: Cost [[0.65094877]]
# Iteration 43: Cost [[0.65000786]]
# Iteration 44: Cost [[0.64906976]]
# Iteration 45: Cost [[0.64813446]]
# Iteration 46: Cost [[0.64720196]]
# Iteration 47: Cost [[0.64627223]]
# Iteration 48: Cost [[0.64534527]]
# Iteration 49: Cost [[0.64442108]]
# Iteration 50: Cost [[0.64349963]]
# Iteration 51: Cost [[0.64258091]]
# Iteration 52: Cost [[0.64166493]]
# Iteration 53: Cost [[0.64075166]]
# Iteration 54: Cost [[0.6398411]]
# Iteration 55: Cost [[0.63893324]]
# Iteration 56: Cost [[0.63802806]]
# Iteration 57: Cost [[0.63712556]]
# Iteration 58: Cost [[0.63622573]]
# Iteration 59: Cost [[0.63532855]]
# Iteration 60: Cost [[0.63443402]]
# Iteration 61: Cost [[0.63354213]]
# Iteration 62: Cost [[0.63265286]]
# Iteration 63: Cost [[0.63176621]]
# Iteration 64: Cost [[0.63088217]]
# Iteration 65: Cost [[0.63000072]]
# Iteration 66: Cost [[0.62912185]]
# Iteration 67: Cost [[0.62824557]]
# Iteration 68: Cost [[0.62737185]]
# Iteration 69: Cost [[0.62650069]]
# Iteration 70: Cost [[0.62563207]]
# Iteration 71: Cost [[0.624766]]
# Iteration 72: Cost [[0.62390245]]
# Iteration 73: Cost [[0.62304141]]
# Iteration 74: Cost [[0.62218289]]
# Iteration 75: Cost [[0.62132687]]
# Iteration 76: Cost [[0.62047333]]
# Iteration 77: Cost [[0.61962228]]
# Iteration 78: Cost [[0.61877369]]
# Iteration 79: Cost [[0.61792756]]
# Iteration 80: Cost [[0.61708389]]
# Iteration 81: Cost [[0.61624266]]
# Iteration 82: Cost [[0.61540386]]
# Iteration 83: Cost [[0.61456748]]
# Iteration 84: Cost [[0.61373352]]
# Iteration 85: Cost [[0.61290196]]
# Iteration 86: Cost [[0.6120728]]
# Iteration 87: Cost [[0.61124602]]
# Iteration 88: Cost [[0.61042162]]
# Iteration 89: Cost [[0.60959959]]
# Iteration 90: Cost [[0.60877992]]
# Iteration 91: Cost [[0.60796259]]
# Iteration 92: Cost [[0.60714761]]
# Iteration 93: Cost [[0.60633496]]
# Iteration 94: Cost [[0.60552463]]
# Iteration 95: Cost [[0.60471661]]
# Iteration 96: Cost [[0.6039109]]
# Iteration 97: Cost [[0.60310749]]
# Iteration 98: Cost [[0.60230636]]
# Iteration 99: Cost [[0.60150751]]
# Iteration 100: Cost [[0.60071093]]
# Iteration 101: Cost [[0.59991661]]
# Iteration 102: Cost [[0.59912454]]
# Iteration 103: Cost [[0.59833472]]
# Iteration 104: Cost [[0.59754713]]
# Iteration 105: Cost [[0.59676177]]
# Iteration 106: Cost [[0.59597862]]
# Iteration 107: Cost [[0.59519768]]
# Iteration 108: Cost [[0.59441895]]
# Iteration 109: Cost [[0.5936424]]
# Iteration 110: Cost [[0.59286805]]
# Iteration 111: Cost [[0.59209586]]
# Iteration 112: Cost [[0.59132584]]
# Iteration 113: Cost [[0.59055799]]
# Iteration 114: Cost [[0.58979228]]
# Iteration 115: Cost [[0.58902871]]
# Iteration 116: Cost [[0.58826728]]
# Iteration 117: Cost [[0.58750797]]
# Iteration 118: Cost [[0.58675079]]
# Iteration 119: Cost [[0.58599571]]
# Iteration 120: Cost [[0.58524273]]
# Iteration 121: Cost [[0.58449185]]
# Iteration 122: Cost [[0.58374305]]
# Iteration 123: Cost [[0.58299633]]
# Iteration 124: Cost [[0.58225168]]
# Iteration 125: Cost [[0.58150909]]
# Iteration 126: Cost [[0.58076855]]
# Iteration 127: Cost [[0.58003007]]
# Iteration 128: Cost [[0.57929361]]
# Iteration 129: Cost [[0.57855919]]
# Iteration 130: Cost [[0.5778268]]
# Iteration 131: Cost [[0.57709641]]
# Iteration 132: Cost [[0.57636804]]
# Iteration 133: Cost [[0.57564166]]
# Iteration 134: Cost [[0.57491728]]
# Iteration 135: Cost [[0.57419488]]
# Iteration 136: Cost [[0.57347446]]
# Iteration 137: Cost [[0.57275601]]
# Iteration 138: Cost [[0.57203952]]
# Iteration 139: Cost [[0.57132498]]
# Iteration 140: Cost [[0.5706124]]
# Iteration 141: Cost [[0.56990175]]
# Iteration 142: Cost [[0.56919303]]
# Iteration 143: Cost [[0.56848624]]
# Iteration 144: Cost [[0.56778137]]
# Iteration 145: Cost [[0.56707841]]
# Iteration 146: Cost [[0.56637735]]
# Iteration 147: Cost [[0.56567819]]
# Iteration 148: Cost [[0.56498092]]
# Iteration 149: Cost [[0.56428553]]
# Iteration 150: Cost [[0.56359201]]
# Iteration 151: Cost [[0.56290036]]
# Iteration 152: Cost [[0.56221058]]
# Iteration 153: Cost [[0.56152264]]
# Iteration 154: Cost [[0.56083656]]
# Iteration 155: Cost [[0.56015231]]
# Iteration 156: Cost [[0.5594699]]
# Iteration 157: Cost [[0.55878932]]
# Iteration 158: Cost [[0.55811055]]
# Iteration 159: Cost [[0.5574336]]
# Iteration 160: Cost [[0.55675845]]
# Iteration 161: Cost [[0.5560851]]
# Iteration 162: Cost [[0.55541354]]
# Iteration 163: Cost [[0.55474377]]
# Iteration 164: Cost [[0.55407578]]
# Iteration 165: Cost [[0.55340956]]
# Iteration 166: Cost [[0.55274511]]
# Iteration 167: Cost [[0.55208242]]
# Iteration 168: Cost [[0.55142148]]
# Iteration 169: Cost [[0.55076228]]
# Iteration 170: Cost [[0.55010483]]
# Iteration 171: Cost [[0.54944911]]
# Iteration 172: Cost [[0.54879511]]
# Iteration 173: Cost [[0.54814284]]
# Iteration 174: Cost [[0.54749228]]
# Iteration 175: Cost [[0.54684343]]
# Iteration 176: Cost [[0.54619628]]
# Iteration 177: Cost [[0.54555082]]
# Iteration 178: Cost [[0.54490706]]
# Iteration 179: Cost [[0.54426497]]
# Iteration 180: Cost [[0.54362457]]
# Iteration 181: Cost [[0.54298583]]
# Iteration 182: Cost [[0.54234876]]
# Iteration 183: Cost [[0.54171335]]
# Iteration 184: Cost [[0.54107959]]
# Iteration 185: Cost [[0.54044747]]
# Iteration 186: Cost [[0.539817]]
# Iteration 187: Cost [[0.53918816]]
# Iteration 188: Cost [[0.53856094]]
# Iteration 189: Cost [[0.53793535]]
# Iteration 190: Cost [[0.53731138]]
# Iteration 191: Cost [[0.53668902]]
# Iteration 192: Cost [[0.53606826]]
# Iteration 193: Cost [[0.53544909]]
# Iteration 194: Cost [[0.53483153]]
# Iteration 195: Cost [[0.53421555]]
# Iteration 196: Cost [[0.53360115]]
# Iteration 197: Cost [[0.53298832]]
# Iteration 198: Cost [[0.53237707]]
# Iteration 199: Cost [[0.53176738]]
# Iteration 200: Cost [[0.53115924]]
# Iteration 201: Cost [[0.53055267]]
# Iteration 202: Cost [[0.52994763]]
# Iteration 203: Cost [[0.52934414]]
# Iteration 204: Cost [[0.52874219]]
# Iteration 205: Cost [[0.52814177]]
# Iteration 206: Cost [[0.52754287]]
# Iteration 207: Cost [[0.52694549]]
# Iteration 208: Cost [[0.52634962]]
# Iteration 209: Cost [[0.52575527]]
# Iteration 210: Cost [[0.52516241]]
# Iteration 211: Cost [[0.52457106]]
# Iteration 212: Cost [[0.5239812]]
# Iteration 213: Cost [[0.52339282]]
# Iteration 214: Cost [[0.52280593]]
# Iteration 215: Cost [[0.52222051]]
# Iteration 216: Cost [[0.52163656]]
# Iteration 217: Cost [[0.52105408]]
# Iteration 218: Cost [[0.52047307]]
# Iteration 219: Cost [[0.5198935]]
# Iteration 220: Cost [[0.51931539]]
# Iteration 221: Cost [[0.51873872]]
# Iteration 222: Cost [[0.51816349]]
# Iteration 223: Cost [[0.5175897]]
# Iteration 224: Cost [[0.51701734]]
# Iteration 225: Cost [[0.5164464]]
# Iteration 226: Cost [[0.51587688]]
# Iteration 227: Cost [[0.51530878]]
# Iteration 228: Cost [[0.51474209]]
# Iteration 229: Cost [[0.5141768]]
# Iteration 230: Cost [[0.51361291]]
# Iteration 231: Cost [[0.51305042]]
# Iteration 232: Cost [[0.51248931]]
# Iteration 233: Cost [[0.5119296]]
# Iteration 234: Cost [[0.51137126]]
# Iteration 235: Cost [[0.5108143]]
# Iteration 236: Cost [[0.51025871]]
# Iteration 237: Cost [[0.50970448]]
# Iteration 238: Cost [[0.50915162]]
# Iteration 239: Cost [[0.50860011]]
# Iteration 240: Cost [[0.50804995]]
# Iteration 241: Cost [[0.50750114]]
# Iteration 242: Cost [[0.50695367]]
# Iteration 243: Cost [[0.50640754]]
# Iteration 244: Cost [[0.50586275]]
# Iteration 245: Cost [[0.50531928]]
# Iteration 246: Cost [[0.50477713]]
# Iteration 247: Cost [[0.50423631]]
# Iteration 248: Cost [[0.5036968]]
# Iteration 249: Cost [[0.5031586]]
# Iteration 250: Cost [[0.5026217]]
# Iteration 251: Cost [[0.5020861]]
# Iteration 252: Cost [[0.5015518]]
# Iteration 253: Cost [[0.5010188]]
# Iteration 254: Cost [[0.50048708]]
# Iteration 255: Cost [[0.49995664]]
# Iteration 256: Cost [[0.49942748]]
# Iteration 257: Cost [[0.4988996]]
# Iteration 258: Cost [[0.49837299]]
# Iteration 259: Cost [[0.49784764]]
# Iteration 260: Cost [[0.49732355]]
# Iteration 261: Cost [[0.49680072]]
# Iteration 262: Cost [[0.49627914]]
# Iteration 263: Cost [[0.49575881]]
# Iteration 264: Cost [[0.49523973]]
# Iteration 265: Cost [[0.49472188]]
# Iteration 266: Cost [[0.49420527]]
# Iteration 267: Cost [[0.49368989]]
# Iteration 268: Cost [[0.49317574]]
# Iteration 269: Cost [[0.49266281]]
# Iteration 270: Cost [[0.4921511]]
# Iteration 271: Cost [[0.49164061]]
# Iteration 272: Cost [[0.49113132]]
# Iteration 273: Cost [[0.49062324]]
# Iteration 274: Cost [[0.49011637]]
# Iteration 275: Cost [[0.48961069]]
# Iteration 276: Cost [[0.4891062]]
# Iteration 277: Cost [[0.48860291]]
# Iteration 278: Cost [[0.4881008]]
# Iteration 279: Cost [[0.48759988]]
# Iteration 280: Cost [[0.48710013]]
# Iteration 281: Cost [[0.48660156]]
# Iteration 282: Cost [[0.48610416]]
# Iteration 283: Cost [[0.48560792]]
# Iteration 284: Cost [[0.48511285]]
# Iteration 285: Cost [[0.48461893]]
# Iteration 286: Cost [[0.48412617]]
# Iteration 287: Cost [[0.48363456]]
# Iteration 288: Cost [[0.4831441]]
# Iteration 289: Cost [[0.48265478]]
# Iteration 290: Cost [[0.4821666]]
# Iteration 291: Cost [[0.48167956]]
# Iteration 292: Cost [[0.48119365]]
# Iteration 293: Cost [[0.48070886]]
# Iteration 294: Cost [[0.4802252]]
# Iteration 295: Cost [[0.47974267]]
# Iteration 296: Cost [[0.47926124]]
# Iteration 297: Cost [[0.47878093]]
# Iteration 298: Cost [[0.47830173]]
# Iteration 299: Cost [[0.47782364]]
# Iteration 300: Cost [[0.47734665]]
# Iteration 301: Cost [[0.47687076]]
# Iteration 302: Cost [[0.47639596]]
# Iteration 303: Cost [[0.47592225]]
# Iteration 304: Cost [[0.47544963]]
# Iteration 305: Cost [[0.4749781]]
# Iteration 306: Cost [[0.47450764]]
# Iteration 307: Cost [[0.47403826]]
# Iteration 308: Cost [[0.47356996]]
# Iteration 309: Cost [[0.47310272]]
# Iteration 310: Cost [[0.47263656]]
# Iteration 311: Cost [[0.47217145]]
# Iteration 312: Cost [[0.47170741]]
# Iteration 313: Cost [[0.47124442]]
# Iteration 314: Cost [[0.47078248]]
# Iteration 315: Cost [[0.47032159]]
# Iteration 316: Cost [[0.46986175]]
# Iteration 317: Cost [[0.46940295]]
# Iteration 318: Cost [[0.46894519]]
# Iteration 319: Cost [[0.46848847]]
# Iteration 320: Cost [[0.46803278]]
# Iteration 321: Cost [[0.46757811]]
# Iteration 322: Cost [[0.46712448]]
# Iteration 323: Cost [[0.46667186]]
# Iteration 324: Cost [[0.46622026]]
# Iteration 325: Cost [[0.46576968]]
# Iteration 326: Cost [[0.46532011]]
# Iteration 327: Cost [[0.46487155]]
# Iteration 328: Cost [[0.464424]]
# Iteration 329: Cost [[0.46397745]]
# Iteration 330: Cost [[0.4635319]]
# Iteration 331: Cost [[0.46308734]]
# Iteration 332: Cost [[0.46264378]]
# Iteration 333: Cost [[0.46220121]]
# Iteration 334: Cost [[0.46175962]]
# Iteration 335: Cost [[0.46131902]]
# Iteration 336: Cost [[0.4608794]]
# Iteration 337: Cost [[0.46044076]]
# Iteration 338: Cost [[0.46000309]]
# Iteration 339: Cost [[0.45956639]]
# Iteration 340: Cost [[0.45913065]]
# Iteration 341: Cost [[0.45869589]]
# Iteration 342: Cost [[0.45826208]]
# Iteration 343: Cost [[0.45782924]]
# Iteration 344: Cost [[0.45739735]]
# Iteration 345: Cost [[0.45696641]]
# Iteration 346: Cost [[0.45653642]]
# Iteration 347: Cost [[0.45610738]]
# Iteration 348: Cost [[0.45567928]]
# Iteration 349: Cost [[0.45525213]]
# Iteration 350: Cost [[0.45482591]]
# Iteration 351: Cost [[0.45440062]]
# Iteration 352: Cost [[0.45397627]]
# Iteration 353: Cost [[0.45355285]]
# Iteration 354: Cost [[0.45313035]]
# Iteration 355: Cost [[0.45270878]]
# Iteration 356: Cost [[0.45228812]]
# Iteration 357: Cost [[0.45186839]]
# Iteration 358: Cost [[0.45144956]]
# Iteration 359: Cost [[0.45103165]]
# Iteration 360: Cost [[0.45061465]]
# Iteration 361: Cost [[0.45019856]]
# Iteration 362: Cost [[0.44978336]]
# Iteration 363: Cost [[0.44936907]]
# Iteration 364: Cost [[0.44895567]]
# Iteration 365: Cost [[0.44854317]]
# Iteration 366: Cost [[0.44813156]]
# Iteration 367: Cost [[0.44772084]]
# Iteration 368: Cost [[0.44731101]]
# Iteration 369: Cost [[0.44690206]]
# Iteration 370: Cost [[0.44649399]]
# Iteration 371: Cost [[0.4460868]]
# Iteration 372: Cost [[0.44568049]]
# Iteration 373: Cost [[0.44527504]]
# Iteration 374: Cost [[0.44487047]]
# Iteration 375: Cost [[0.44446677]]
# Iteration 376: Cost [[0.44406392]]
# Iteration 377: Cost [[0.44366195]]
# Iteration 378: Cost [[0.44326083]]
# Iteration 379: Cost [[0.44286056]]
# Iteration 380: Cost [[0.44246116]]
# Iteration 381: Cost [[0.4420626]]
# Iteration 382: Cost [[0.44166489]]
# Iteration 383: Cost [[0.44126803]]
# Iteration 384: Cost [[0.44087201]]
# Iteration 385: Cost [[0.44047683]]
# Iteration 386: Cost [[0.4400825]]
# Iteration 387: Cost [[0.43968899]]
# Iteration 388: Cost [[0.43929632]]
# Iteration 389: Cost [[0.43890449]]
# Iteration 390: Cost [[0.43851348]]
# Iteration 391: Cost [[0.43812329]]
# Iteration 392: Cost [[0.43773393]]
# Iteration 393: Cost [[0.43734539]]
# Iteration 394: Cost [[0.43695767]]
# Iteration 395: Cost [[0.43657076]]
# Iteration 396: Cost [[0.43618467]]
# Iteration 397: Cost [[0.43579939]]
# Iteration 398: Cost [[0.43541492]]
# Iteration 399: Cost [[0.43503125]]
# Iteration 400: Cost [[0.43464839]]
# Iteration 401: Cost [[0.43426633]]
# Iteration 402: Cost [[0.43388506]]
# Iteration 403: Cost [[0.4335046]]
# Iteration 404: Cost [[0.43312492]]
# Iteration 405: Cost [[0.43274604]]
# Iteration 406: Cost [[0.43236795]]
# Iteration 407: Cost [[0.43199065]]
# Iteration 408: Cost [[0.43161413]]
# Iteration 409: Cost [[0.43123839]]
# Iteration 410: Cost [[0.43086343]]
# Iteration 411: Cost [[0.43048925]]
# Iteration 412: Cost [[0.43011584]]
# Iteration 413: Cost [[0.42974321]]
# Iteration 414: Cost [[0.42937135]]
# Iteration 415: Cost [[0.42900026]]
# Iteration 416: Cost [[0.42862993]]
# Iteration 417: Cost [[0.42826036]]
# Iteration 418: Cost [[0.42789156]]
# Iteration 419: Cost [[0.42752352]]
# Iteration 420: Cost [[0.42715623]]
# Iteration 421: Cost [[0.4267897]]
# Iteration 422: Cost [[0.42642392]]
# Iteration 423: Cost [[0.42605889]]
# Iteration 424: Cost [[0.42569461]]
# Iteration 425: Cost [[0.42533108]]
# Iteration 426: Cost [[0.42496829]]
# Iteration 427: Cost [[0.42460624]]
# Iteration 428: Cost [[0.42424493]]
# Iteration 429: Cost [[0.42388435]]
# Iteration 430: Cost [[0.42352452]]
# Iteration 431: Cost [[0.42316541]]
# Iteration 432: Cost [[0.42280704]]
# Iteration 433: Cost [[0.42244939]]
# Iteration 434: Cost [[0.42209247]]
# Iteration 435: Cost [[0.42173627]]
# Iteration 436: Cost [[0.4213808]]
# Iteration 437: Cost [[0.42102605]]
# Iteration 438: Cost [[0.42067201]]
# Iteration 439: Cost [[0.42031869]]
# Iteration 440: Cost [[0.41996609]]
# Iteration 441: Cost [[0.41961419]]
# Iteration 442: Cost [[0.41926301]]
# Iteration 443: Cost [[0.41891253]]
# Iteration 444: Cost [[0.41856276]]
# Iteration 445: Cost [[0.41821369]]
# Iteration 446: Cost [[0.41786532]]
# Iteration 447: Cost [[0.41751766]]
# Iteration 448: Cost [[0.41717069]]
# Iteration 449: Cost [[0.41682441]]
# Iteration 450: Cost [[0.41647883]]
# Iteration 451: Cost [[0.41613394]]
# Iteration 452: Cost [[0.41578974]]
# Iteration 453: Cost [[0.41544623]]
# Iteration 454: Cost [[0.4151034]]
# Iteration 455: Cost [[0.41476126]]
# Iteration 456: Cost [[0.41441979]]
# Iteration 457: Cost [[0.41407901]]
# Iteration 458: Cost [[0.41373891]]
# Iteration 459: Cost [[0.41339948]]
# Iteration 460: Cost [[0.41306072]]
# Iteration 461: Cost [[0.41272264]]
# Iteration 462: Cost [[0.41238522]]
# Iteration 463: Cost [[0.41204848]]
# Iteration 464: Cost [[0.41171239]]
# Iteration 465: Cost [[0.41137698]]
# Iteration 466: Cost [[0.41104222]]
# Iteration 467: Cost [[0.41070813]]
# Iteration 468: Cost [[0.4103747]]
# Iteration 469: Cost [[0.41004192]]
# Iteration 470: Cost [[0.40970979]]
# Iteration 471: Cost [[0.40937832]]
# Iteration 472: Cost [[0.4090475]]
# Iteration 473: Cost [[0.40871733]]
# Iteration 474: Cost [[0.40838781]]
# Iteration 475: Cost [[0.40805893]]
# Iteration 476: Cost [[0.4077307]]
# Iteration 477: Cost [[0.40740311]]
# Iteration 478: Cost [[0.40707615]]
# Iteration 479: Cost [[0.40674984]]
# Iteration 480: Cost [[0.40642416]]
# Iteration 481: Cost [[0.40609912]]
# Iteration 482: Cost [[0.40577471]]
# Iteration 483: Cost [[0.40545093]]
# Iteration 484: Cost [[0.40512778]]
# Iteration 485: Cost [[0.40480526]]
# Iteration 486: Cost [[0.40448337]]
# Iteration 487: Cost [[0.4041621]]
# Iteration 488: Cost [[0.40384145]]
# Iteration 489: Cost [[0.40352142]]
# Iteration 490: Cost [[0.40320201]]
# Iteration 491: Cost [[0.40288322]]
# Iteration 492: Cost [[0.40256504]]
# Iteration 493: Cost [[0.40224748]]
# Iteration 494: Cost [[0.40193053]]
# Iteration 495: Cost [[0.40161419]]
# Iteration 496: Cost [[0.40129846]]
# Iteration 497: Cost [[0.40098333]]
# Iteration 498: Cost [[0.40066881]]
# Iteration 499: Cost [[0.4003549]]
# Iteration 500: Cost [[0.40004158]]
# Iteration 501: Cost [[0.39972887]]
# Iteration 502: Cost [[0.39941676]]
# Iteration 503: Cost [[0.39910524]]
# Iteration 504: Cost [[0.39879432]]
# Iteration 505: Cost [[0.39848399]]
# Iteration 506: Cost [[0.39817425]]
# Iteration 507: Cost [[0.3978651]]
# Iteration 508: Cost [[0.39755655]]
# Iteration 509: Cost [[0.39724858]]
# Iteration 510: Cost [[0.39694119]]
# Iteration 511: Cost [[0.39663439]]
# Iteration 512: Cost [[0.39632817]]
# Iteration 513: Cost [[0.39602254]]
# Iteration 514: Cost [[0.39571748]]
# Iteration 515: Cost [[0.395413]]
# Iteration 516: Cost [[0.39510909]]
# Iteration 517: Cost [[0.39480576]]
# Iteration 518: Cost [[0.39450301]]
# Iteration 519: Cost [[0.39420082]]
# Iteration 520: Cost [[0.3938992]]
# Iteration 521: Cost [[0.39359816]]
# Iteration 522: Cost [[0.39329767]]
# Iteration 523: Cost [[0.39299776]]
# Iteration 524: Cost [[0.39269841]]
# Iteration 525: Cost [[0.39239962]]
# Iteration 526: Cost [[0.39210139]]
# Iteration 527: Cost [[0.39180372]]
# Iteration 528: Cost [[0.3915066]]
# Iteration 529: Cost [[0.39121005]]
# Iteration 530: Cost [[0.39091404]]
# Iteration 531: Cost [[0.39061859]]
# Iteration 532: Cost [[0.3903237]]
# Iteration 533: Cost [[0.39002935]]
# Iteration 534: Cost [[0.38973555]]
# Iteration 535: Cost [[0.3894423]]
# Iteration 536: Cost [[0.38914959]]
# Iteration 537: Cost [[0.38885743]]
# Iteration 538: Cost [[0.38856581]]
# Iteration 539: Cost [[0.38827473]]
# Iteration 540: Cost [[0.38798419]]
# Iteration 541: Cost [[0.38769419]]
# Iteration 542: Cost [[0.38740473]]
# Iteration 543: Cost [[0.3871158]]
# Iteration 544: Cost [[0.38682741]]
# Iteration 545: Cost [[0.38653955]]
# Iteration 546: Cost [[0.38625222]]
# Iteration 547: Cost [[0.38596542]]
# Iteration 548: Cost [[0.38567915]]
# Iteration 549: Cost [[0.38539341]]
# Iteration 550: Cost [[0.38510819]]
# Iteration 551: Cost [[0.38482349]]
# Iteration 552: Cost [[0.38453932]]
# Iteration 553: Cost [[0.38425567]]
# Iteration 554: Cost [[0.38397254]]
# Iteration 555: Cost [[0.38368993]]
# Iteration 556: Cost [[0.38340784]]
# Iteration 557: Cost [[0.38312626]]
# Iteration 558: Cost [[0.38284519]]
# Iteration 559: Cost [[0.38256464]]
# Iteration 560: Cost [[0.38228461]]
# Iteration 561: Cost [[0.38200508]]
# Iteration 562: Cost [[0.38172606]]
# Iteration 563: Cost [[0.38144755]]
# Iteration 564: Cost [[0.38116955]]
# Iteration 565: Cost [[0.38089205]]
# Iteration 566: Cost [[0.38061505]]
# Iteration 567: Cost [[0.38033856]]
# Iteration 568: Cost [[0.38006257]]
# Iteration 569: Cost [[0.37978708]]
# Iteration 570: Cost [[0.37951208]]
# Iteration 571: Cost [[0.37923759]]
# Iteration 572: Cost [[0.37896359]]
# Iteration 573: Cost [[0.37869008]]
# Iteration 574: Cost [[0.37841707]]
# Iteration 575: Cost [[0.37814455]]
# Iteration 576: Cost [[0.37787253]]
# Iteration 577: Cost [[0.37760099]]
# Iteration 578: Cost [[0.37732994]]
# Iteration 579: Cost [[0.37705937]]
# Iteration 580: Cost [[0.3767893]]
# Iteration 581: Cost [[0.3765197]]
# Iteration 582: Cost [[0.3762506]]
# Iteration 583: Cost [[0.37598197]]
# Iteration 584: Cost [[0.37571382]]
# Iteration 585: Cost [[0.37544615]]
# Iteration 586: Cost [[0.37517897]]
# Iteration 587: Cost [[0.37491225]]
# Iteration 588: Cost [[0.37464602]]
# Iteration 589: Cost [[0.37438026]]
# Iteration 590: Cost [[0.37411497]]
# Iteration 591: Cost [[0.37385015]]
# Iteration 592: Cost [[0.37358581]]
# Iteration 593: Cost [[0.37332193]]
# Iteration 594: Cost [[0.37305853]]
# Iteration 595: Cost [[0.37279559]]
# Iteration 596: Cost [[0.37253311]]
# Iteration 597: Cost [[0.37227111]]
# Iteration 598: Cost [[0.37200956]]
# Iteration 599: Cost [[0.37174848]]
# Iteration 600: Cost [[0.37148786]]
# Iteration 601: Cost [[0.3712277]]
# Iteration 602: Cost [[0.370968]]
# Iteration 603: Cost [[0.37070876]]
# Iteration 604: Cost [[0.37044997]]
# Iteration 605: Cost [[0.37019164]]
# Iteration 606: Cost [[0.36993376]]
# Iteration 607: Cost [[0.36967634]]
# Iteration 608: Cost [[0.36941937]]
# Iteration 609: Cost [[0.36916285]]
# Iteration 610: Cost [[0.36890678]]
# Iteration 611: Cost [[0.36865116]]
# Iteration 612: Cost [[0.36839599]]
# Iteration 613: Cost [[0.36814126]]
# Iteration 614: Cost [[0.36788698]]
# Iteration 615: Cost [[0.36763314]]
# Iteration 616: Cost [[0.36737974]]
# Iteration 617: Cost [[0.36712679]]
# Iteration 618: Cost [[0.36687428]]
# Iteration 619: Cost [[0.36662221]]
# Iteration 620: Cost [[0.36637057]]
# Iteration 621: Cost [[0.36611937]]
# Iteration 622: Cost [[0.36586861]]
# Iteration 623: Cost [[0.36561829]]
# Iteration 624: Cost [[0.3653684]]
# Iteration 625: Cost [[0.36511894]]
# Iteration 626: Cost [[0.36486992]]
# Iteration 627: Cost [[0.36462132]]
# Iteration 628: Cost [[0.36437316]]
# Iteration 629: Cost [[0.36412542]]
# Iteration 630: Cost [[0.36387811]]
# Iteration 631: Cost [[0.36363123]]
# Iteration 632: Cost [[0.36338478]]
# Iteration 633: Cost [[0.36313875]]
# Iteration 634: Cost [[0.36289314]]
# Iteration 635: Cost [[0.36264795]]
# Iteration 636: Cost [[0.36240319]]
# Iteration 637: Cost [[0.36215885]]
# Iteration 638: Cost [[0.36191492]]
# Iteration 639: Cost [[0.36167142]]
# Iteration 640: Cost [[0.36142833]]
# Iteration 641: Cost [[0.36118566]]
# Iteration 642: Cost [[0.3609434]]
# Iteration 643: Cost [[0.36070155]]
# Iteration 644: Cost [[0.36046012]]
# Iteration 645: Cost [[0.36021911]]
# Iteration 646: Cost [[0.3599785]]
# Iteration 647: Cost [[0.3597383]]
# Iteration 648: Cost [[0.35949852]]
# Iteration 649: Cost [[0.35925914]]
# Iteration 650: Cost [[0.35902016]]
# Iteration 651: Cost [[0.3587816]]
# Iteration 652: Cost [[0.35854343]]
# Iteration 653: Cost [[0.35830568]]
# Iteration 654: Cost [[0.35806832]]
# Iteration 655: Cost [[0.35783137]]
# Iteration 656: Cost [[0.35759482]]
# Iteration 657: Cost [[0.35735867]]
# Iteration 658: Cost [[0.35712292]]
# Iteration 659: Cost [[0.35688756]]
# Iteration 660: Cost [[0.35665261]]
# Iteration 661: Cost [[0.35641805]]
# Iteration 662: Cost [[0.35618388]]
# Iteration 663: Cost [[0.35595011]]
# Iteration 664: Cost [[0.35571673]]
# Iteration 665: Cost [[0.35548375]]
# Iteration 666: Cost [[0.35525115]]
# Iteration 667: Cost [[0.35501895]]
# Iteration 668: Cost [[0.35478714]]
# Iteration 669: Cost [[0.35455571]]
# Iteration 670: Cost [[0.35432467]]
# Iteration 671: Cost [[0.35409402]]
# Iteration 672: Cost [[0.35386376]]
# Iteration 673: Cost [[0.35363388]]
# Iteration 674: Cost [[0.35340438]]
# Iteration 675: Cost [[0.35317527]]
# Iteration 676: Cost [[0.35294654]]
# Iteration 677: Cost [[0.35271819]]
# Iteration 678: Cost [[0.35249022]]
# Iteration 679: Cost [[0.35226263]]
# Iteration 680: Cost [[0.35203542]]
# Iteration 681: Cost [[0.35180858]]
# Iteration 682: Cost [[0.35158212]]
# Iteration 683: Cost [[0.35135604]]
# Iteration 684: Cost [[0.35113033]]
# Iteration 685: Cost [[0.350905]]
# Iteration 686: Cost [[0.35068004]]
# Iteration 687: Cost [[0.35045545]]
# Iteration 688: Cost [[0.35023123]]
# Iteration 689: Cost [[0.35000738]]
# Iteration 690: Cost [[0.34978391]]
# Iteration 691: Cost [[0.3495608]]
# Iteration 692: Cost [[0.34933806]]
# Iteration 693: Cost [[0.34911568]]
# Iteration 694: Cost [[0.34889367]]
# Iteration 695: Cost [[0.34867203]]
# Iteration 696: Cost [[0.34845075]]
# Iteration 697: Cost [[0.34822983]]
# Iteration 698: Cost [[0.34800928]]
# Iteration 699: Cost [[0.34778909]]
# Iteration 700: Cost [[0.34756926]]
# Iteration 701: Cost [[0.34734978]]
# Iteration 702: Cost [[0.34713067]]
# Iteration 703: Cost [[0.34691192]]
# Iteration 704: Cost [[0.34669352]]
# Iteration 705: Cost [[0.34647548]]
# Iteration 706: Cost [[0.3462578]]
# Iteration 707: Cost [[0.34604047]]
# Iteration 708: Cost [[0.34582349]]
# Iteration 709: Cost [[0.34560687]]
# Iteration 710: Cost [[0.3453906]]
# Iteration 711: Cost [[0.34517468]]
# Iteration 712: Cost [[0.34495911]]
# Iteration 713: Cost [[0.34474389]]
# Iteration 714: Cost [[0.34452902]]
# Iteration 715: Cost [[0.3443145]]
# Iteration 716: Cost [[0.34410032]]
# Iteration 717: Cost [[0.3438865]]
# Iteration 718: Cost [[0.34367301]]
# Iteration 719: Cost [[0.34345988]]
# Iteration 720: Cost [[0.34324709]]
# Iteration 721: Cost [[0.34303464]]
# Iteration 722: Cost [[0.34282253]]
# Iteration 723: Cost [[0.34261076]]
# Iteration 724: Cost [[0.34239934]]
# Iteration 725: Cost [[0.34218826]]
# Iteration 726: Cost [[0.34197751]]
# Iteration 727: Cost [[0.3417671]]
# Iteration 728: Cost [[0.34155704]]
# Iteration 729: Cost [[0.3413473]]
# Iteration 730: Cost [[0.34113791]]
# Iteration 731: Cost [[0.34092885]]
# Iteration 732: Cost [[0.34072012]]
# Iteration 733: Cost [[0.34051173]]
# Iteration 734: Cost [[0.34030368]]
# Iteration 735: Cost [[0.34009595]]
# Iteration 736: Cost [[0.33988856]]
# Iteration 737: Cost [[0.33968149]]
# Iteration 738: Cost [[0.33947476]]
# Iteration 739: Cost [[0.33926835]]
# Iteration 740: Cost [[0.33906228]]
# Iteration 741: Cost [[0.33885653]]
# Iteration 742: Cost [[0.33865111]]
# Iteration 743: Cost [[0.33844602]]
# Iteration 744: Cost [[0.33824125]]
# Iteration 745: Cost [[0.3380368]]
# Iteration 746: Cost [[0.33783268]]
# Iteration 747: Cost [[0.33762889]]
# Iteration 748: Cost [[0.33742541]]
# Iteration 749: Cost [[0.33722226]]
# Iteration 750: Cost [[0.33701943]]
# Iteration 751: Cost [[0.33681691]]
# Iteration 752: Cost [[0.33661472]]
# Iteration 753: Cost [[0.33641285]]
# Iteration 754: Cost [[0.3362113]]
# Iteration 755: Cost [[0.33601006]]
# Iteration 756: Cost [[0.33580914]]
# Iteration 757: Cost [[0.33560853]]
# Iteration 758: Cost [[0.33540824]]
# Iteration 759: Cost [[0.33520827]]
# Iteration 760: Cost [[0.33500861]]
# Iteration 761: Cost [[0.33480926]]
# Iteration 762: Cost [[0.33461022]]
# Iteration 763: Cost [[0.3344115]]
# Iteration 764: Cost [[0.33421309]]
# Iteration 765: Cost [[0.33401498]]
# Iteration 766: Cost [[0.33381719]]
# Iteration 767: Cost [[0.33361971]]
# Iteration 768: Cost [[0.33342253]]
# Iteration 769: Cost [[0.33322566]]
# Iteration 770: Cost [[0.3330291]]
# Iteration 771: Cost [[0.33283284]]
# Iteration 772: Cost [[0.33263689]]
# Iteration 773: Cost [[0.33244125]]
# Iteration 774: Cost [[0.3322459]]
# Iteration 775: Cost [[0.33205087]]
# Iteration 776: Cost [[0.33185613]]
# Iteration 777: Cost [[0.3316617]]
# Iteration 778: Cost [[0.33146756]]
# Iteration 779: Cost [[0.33127373]]
# Iteration 780: Cost [[0.3310802]]
# Iteration 781: Cost [[0.33088697]]
# Iteration 782: Cost [[0.33069403]]
# Iteration 783: Cost [[0.3305014]]
# Iteration 784: Cost [[0.33030906]]
# Iteration 785: Cost [[0.33011702]]
# Iteration 786: Cost [[0.32992527]]
# Iteration 787: Cost [[0.32973382]]
# Iteration 788: Cost [[0.32954266]]
# Iteration 789: Cost [[0.3293518]]
# Iteration 790: Cost [[0.32916123]]
# Iteration 791: Cost [[0.32897095]]
# Iteration 792: Cost [[0.32878097]]
# Iteration 793: Cost [[0.32859128]]
# Iteration 794: Cost [[0.32840187]]
# Iteration 795: Cost [[0.32821276]]
# Iteration 796: Cost [[0.32802394]]
# Iteration 797: Cost [[0.3278354]]
# Iteration 798: Cost [[0.32764716]]
# Iteration 799: Cost [[0.3274592]]
# Iteration 800: Cost [[0.32727153]]
# Iteration 801: Cost [[0.32708414]]
# Iteration 802: Cost [[0.32689704]]
# Iteration 803: Cost [[0.32671023]]
# Iteration 804: Cost [[0.3265237]]
# Iteration 805: Cost [[0.32633745]]
# Iteration 806: Cost [[0.32615149]]
# Iteration 807: Cost [[0.3259658]]
# Iteration 808: Cost [[0.3257804]]
# Iteration 809: Cost [[0.32559529]]
# Iteration 810: Cost [[0.32541045]]
# Iteration 811: Cost [[0.32522589]]
# Iteration 812: Cost [[0.32504161]]
# Iteration 813: Cost [[0.32485761]]
# Iteration 814: Cost [[0.32467389]]
# Iteration 815: Cost [[0.32449045]]
# Iteration 816: Cost [[0.32430728]]
# Iteration 817: Cost [[0.32412439]]
# Iteration 818: Cost [[0.32394178]]
# Iteration 819: Cost [[0.32375944]]
# Iteration 820: Cost [[0.32357737]]
# Iteration 821: Cost [[0.32339558]]
# Iteration 822: Cost [[0.32321406]]
# Iteration 823: Cost [[0.32303282]]
# Iteration 824: Cost [[0.32285184]]
# Iteration 825: Cost [[0.32267114]]
# Iteration 826: Cost [[0.32249071]]
# Iteration 827: Cost [[0.32231055]]
# Iteration 828: Cost [[0.32213066]]
# Iteration 829: Cost [[0.32195104]]
# Iteration 830: Cost [[0.32177168]]
# Iteration 831: Cost [[0.3215926]]
# Iteration 832: Cost [[0.32141378]]
# Iteration 833: Cost [[0.32123523]]
# Iteration 834: Cost [[0.32105695]]
# Iteration 835: Cost [[0.32087893]]
# Iteration 836: Cost [[0.32070118]]
# Iteration 837: Cost [[0.32052369]]
# Iteration 838: Cost [[0.32034646]]
# Iteration 839: Cost [[0.3201695]]
# Iteration 840: Cost [[0.3199928]]
# Iteration 841: Cost [[0.31981637]]
# Iteration 842: Cost [[0.31964019]]
# Iteration 843: Cost [[0.31946428]]
# Iteration 844: Cost [[0.31928863]]
# Iteration 845: Cost [[0.31911323]]
# Iteration 846: Cost [[0.3189381]]
# Iteration 847: Cost [[0.31876323]]
# Iteration 848: Cost [[0.31858861]]
# Iteration 849: Cost [[0.31841425]]
# Iteration 850: Cost [[0.31824015]]
# Iteration 851: Cost [[0.31806631]]
# Iteration 852: Cost [[0.31789272]]
# Iteration 853: Cost [[0.31771939]]
# Iteration 854: Cost [[0.31754631]]
# Iteration 855: Cost [[0.31737349]]
# Iteration 856: Cost [[0.31720092]]
# Iteration 857: Cost [[0.3170286]]
# Iteration 858: Cost [[0.31685654]]
# Iteration 859: Cost [[0.31668473]]
# Iteration 860: Cost [[0.31651317]]
# Iteration 861: Cost [[0.31634186]]
# Iteration 862: Cost [[0.31617081]]
# Iteration 863: Cost [[0.316]]
# Iteration 864: Cost [[0.31582945]]
# Iteration 865: Cost [[0.31565914]]
# Iteration 866: Cost [[0.31548908]]
# Iteration 867: Cost [[0.31531927]]
# Iteration 868: Cost [[0.31514971]]
# Iteration 869: Cost [[0.31498039]]
# Iteration 870: Cost [[0.31481132]]
# Iteration 871: Cost [[0.3146425]]
# Iteration 872: Cost [[0.31447392]]
# Iteration 873: Cost [[0.31430559]]
# Iteration 874: Cost [[0.3141375]]
# Iteration 875: Cost [[0.31396966]]
# Iteration 876: Cost [[0.31380206]]
# Iteration 877: Cost [[0.3136347]]
# Iteration 878: Cost [[0.31346758]]
# Iteration 879: Cost [[0.31330071]]
# Iteration 880: Cost [[0.31313408]]
# Iteration 881: Cost [[0.31296768]]
# Iteration 882: Cost [[0.31280153]]
# Iteration 883: Cost [[0.31263562]]
# Iteration 884: Cost [[0.31246995]]
# Iteration 885: Cost [[0.31230452]]
# Iteration 886: Cost [[0.31213932]]
# Iteration 887: Cost [[0.31197437]]
# Iteration 888: Cost [[0.31180965]]
# Iteration 889: Cost [[0.31164517]]
# Iteration 890: Cost [[0.31148092]]
# Iteration 891: Cost [[0.31131691]]
# Iteration 892: Cost [[0.31115313]]
# Iteration 893: Cost [[0.3109896]]
# Iteration 894: Cost [[0.31082629]]
# Iteration 895: Cost [[0.31066322]]
# Iteration 896: Cost [[0.31050038]]
# Iteration 897: Cost [[0.31033778]]
# Iteration 898: Cost [[0.3101754]]
# Iteration 899: Cost [[0.31001326]]
# Iteration 900: Cost [[0.30985135]]
# Iteration 901: Cost [[0.30968968]]
# Iteration 902: Cost [[0.30952823]]
# Iteration 903: Cost [[0.30936701]]
# Iteration 904: Cost [[0.30920602]]
# Iteration 905: Cost [[0.30904526]]
# Iteration 906: Cost [[0.30888473]]
# Iteration 907: Cost [[0.30872443]]
# Iteration 908: Cost [[0.30856436]]
# Iteration 909: Cost [[0.30840451]]
# Iteration 910: Cost [[0.30824489]]
# Iteration 911: Cost [[0.3080855]]
# Iteration 912: Cost [[0.30792633]]
# Iteration 913: Cost [[0.30776739]]
# Iteration 914: Cost [[0.30760867]]
# Iteration 915: Cost [[0.30745018]]
# Iteration 916: Cost [[0.30729191]]
# Iteration 917: Cost [[0.30713386]]
# Iteration 918: Cost [[0.30697604]]
# Iteration 919: Cost [[0.30681844]]
# Iteration 920: Cost [[0.30666106]]
# Iteration 921: Cost [[0.30650391]]
# Iteration 922: Cost [[0.30634697]]
# Iteration 923: Cost [[0.30619026]]
# Iteration 924: Cost [[0.30603376]]
# Iteration 925: Cost [[0.30587749]]
# Iteration 926: Cost [[0.30572143]]
# Iteration 927: Cost [[0.3055656]]
# Iteration 928: Cost [[0.30540998]]
# Iteration 929: Cost [[0.30525458]]
# Iteration 930: Cost [[0.3050994]]
# Iteration 931: Cost [[0.30494444]]
# Iteration 932: Cost [[0.30478969]]
# Iteration 933: Cost [[0.30463516]]
# Iteration 934: Cost [[0.30448085]]
# Iteration 935: Cost [[0.30432675]]
# Iteration 936: Cost [[0.30417286]]
# Iteration 937: Cost [[0.30401919]]
# Iteration 938: Cost [[0.30386574]]
# Iteration 939: Cost [[0.3037125]]
# Iteration 940: Cost [[0.30355947]]
# Iteration 941: Cost [[0.30340665]]
# Iteration 942: Cost [[0.30325405]]
# Iteration 943: Cost [[0.30310166]]
# Iteration 944: Cost [[0.30294948]]
# Iteration 945: Cost [[0.30279751]]
# Iteration 946: Cost [[0.30264575]]
# Iteration 947: Cost [[0.3024942]]
# Iteration 948: Cost [[0.30234286]]
# Iteration 949: Cost [[0.30219174]]
# Iteration 950: Cost [[0.30204082]]
# Iteration 951: Cost [[0.30189011]]
# Iteration 952: Cost [[0.3017396]]
# Iteration 953: Cost [[0.30158931]]
# Iteration 954: Cost [[0.30143922]]
# Iteration 955: Cost [[0.30128934]]
# Iteration 956: Cost [[0.30113967]]
# Iteration 957: Cost [[0.3009902]]
# Iteration 958: Cost [[0.30084094]]
# Iteration 959: Cost [[0.30069188]]
# Iteration 960: Cost [[0.30054303]]
# Iteration 961: Cost [[0.30039438]]
# Iteration 962: Cost [[0.30024594]]
# Iteration 963: Cost [[0.3000977]]
# Iteration 964: Cost [[0.29994966]]
# Iteration 965: Cost [[0.29980182]]
# Iteration 966: Cost [[0.29965419]]
# Iteration 967: Cost [[0.29950676]]
# Iteration 968: Cost [[0.29935954]]
# Iteration 969: Cost [[0.29921251]]
# Iteration 970: Cost [[0.29906568]]
# Iteration 971: Cost [[0.29891906]]
# Iteration 972: Cost [[0.29877263]]
# Iteration 973: Cost [[0.29862641]]
# Iteration 974: Cost [[0.29848038]]
# Iteration 975: Cost [[0.29833455]]
# Iteration 976: Cost [[0.29818892]]
# Iteration 977: Cost [[0.29804349]]
# Iteration 978: Cost [[0.29789826]]
# Iteration 979: Cost [[0.29775322]]
# Iteration 980: Cost [[0.29760838]]
# Iteration 981: Cost [[0.29746374]]
# Iteration 982: Cost [[0.29731929]]
# Iteration 983: Cost [[0.29717504]]
# Iteration 984: Cost [[0.29703099]]
# Iteration 985: Cost [[0.29688713]]
# Iteration 986: Cost [[0.29674346]]
# Iteration 987: Cost [[0.29659999]]
# Iteration 988: Cost [[0.29645671]]
# Iteration 989: Cost [[0.29631362]]
# Iteration 990: Cost [[0.29617073]]
# Iteration 991: Cost [[0.29602803]]
# Iteration 992: Cost [[0.29588553]]
# Iteration 993: Cost [[0.29574321]]
# Iteration 994: Cost [[0.29560109]]
# Iteration 995: Cost [[0.29545915]]
# Iteration 996: Cost [[0.29531741]]
# Iteration 997: Cost [[0.29517586]]
# Iteration 998: Cost [[0.2950345]]
# Iteration 999: Cost [[0.29489333]]
# Iteration 1000: Cost [[0.29475235]]
# Iteration 1001: Cost [[0.29461155]]
# Iteration 1002: Cost [[0.29447095]]
# Iteration 1003: Cost [[0.29433053]]
# Iteration 1004: Cost [[0.2941903]]
# Iteration 1005: Cost [[0.29405026]]
# Iteration 1006: Cost [[0.29391041]]
# Iteration 1007: Cost [[0.29377074]]
# Iteration 1008: Cost [[0.29363126]]
# Iteration 1009: Cost [[0.29349196]]
# Iteration 1010: Cost [[0.29335285]]
# Iteration 1011: Cost [[0.29321393]]
# Iteration 1012: Cost [[0.29307519]]
# Iteration 1013: Cost [[0.29293663]]
# Iteration 1014: Cost [[0.29279826]]
# Iteration 1015: Cost [[0.29266008]]
# Iteration 1016: Cost [[0.29252207]]
# Iteration 1017: Cost [[0.29238425]]
# Iteration 1018: Cost [[0.29224661]]
# Iteration 1019: Cost [[0.29210916]]
# Iteration 1020: Cost [[0.29197189]]
# Iteration 1021: Cost [[0.2918348]]
# Iteration 1022: Cost [[0.29169789]]
# Iteration 1023: Cost [[0.29156116]]
# Iteration 1024: Cost [[0.29142461]]
# Iteration 1025: Cost [[0.29128824]]
# Iteration 1026: Cost [[0.29115205]]
# Iteration 1027: Cost [[0.29101604]]
# Iteration 1028: Cost [[0.29088021]]
# Iteration 1029: Cost [[0.29074456]]
# Iteration 1030: Cost [[0.29060909]]
# Iteration 1031: Cost [[0.2904738]]
# Iteration 1032: Cost [[0.29033868]]
# Iteration 1033: Cost [[0.29020375]]
# Iteration 1034: Cost [[0.29006899]]
# Iteration 1035: Cost [[0.2899344]]
# Iteration 1036: Cost [[0.2898]]
# Iteration 1037: Cost [[0.28966576]]
# Iteration 1038: Cost [[0.28953171]]
# Iteration 1039: Cost [[0.28939783]]
# Iteration 1040: Cost [[0.28926413]]
# Iteration 1041: Cost [[0.2891306]]
# Iteration 1042: Cost [[0.28899724]]
# Iteration 1043: Cost [[0.28886406]]
# Iteration 1044: Cost [[0.28873105]]
# Iteration 1045: Cost [[0.28859822]]
# Iteration 1046: Cost [[0.28846556]]
# Iteration 1047: Cost [[0.28833307]]
# Iteration 1048: Cost [[0.28820076]]
# Iteration 1049: Cost [[0.28806862]]
# Iteration 1050: Cost [[0.28793665]]
# Iteration 1051: Cost [[0.28780485]]
# Iteration 1052: Cost [[0.28767322]]
# Iteration 1053: Cost [[0.28754176]]
# Iteration 1054: Cost [[0.28741048]]
# Iteration 1055: Cost [[0.28727936]]
# Iteration 1056: Cost [[0.28714842]]
# Iteration 1057: Cost [[0.28701764]]
# Iteration 1058: Cost [[0.28688703]]
# Iteration 1059: Cost [[0.28675659]]
# Iteration 1060: Cost [[0.28662633]]
# Iteration 1061: Cost [[0.28649622]]
# Iteration 1062: Cost [[0.28636629]]
# Iteration 1063: Cost [[0.28623653]]
# Iteration 1064: Cost [[0.28610693]]
# Iteration 1065: Cost [[0.2859775]]
# Iteration 1066: Cost [[0.28584823]]
# Iteration 1067: Cost [[0.28571914]]
# Iteration 1068: Cost [[0.28559021]]
# Iteration 1069: Cost [[0.28546144]]
# Iteration 1070: Cost [[0.28533284]]
# Iteration 1071: Cost [[0.28520441]]
# Iteration 1072: Cost [[0.28507614]]
# Iteration 1073: Cost [[0.28494803]]
# Iteration 1074: Cost [[0.28482009]]
# Iteration 1075: Cost [[0.28469231]]
# Iteration 1076: Cost [[0.2845647]]
# Iteration 1077: Cost [[0.28443725]]
# Iteration 1078: Cost [[0.28430996]]
# Iteration 1079: Cost [[0.28418284]]
# Iteration 1080: Cost [[0.28405588]]
# Iteration 1081: Cost [[0.28392908]]
# Iteration 1082: Cost [[0.28380244]]
# Iteration 1083: Cost [[0.28367597]]
# Iteration 1084: Cost [[0.28354965]]
# Iteration 1085: Cost [[0.2834235]]
# Iteration 1086: Cost [[0.28329751]]
# Iteration 1087: Cost [[0.28317167]]
# Iteration 1088: Cost [[0.283046]]
# Iteration 1089: Cost [[0.28292049]]
# Iteration 1090: Cost [[0.28279513]]
# Iteration 1091: Cost [[0.28266994]]
# Iteration 1092: Cost [[0.2825449]]
# Iteration 1093: Cost [[0.28242003]]
# Iteration 1094: Cost [[0.28229531]]
# Iteration 1095: Cost [[0.28217075]]
# Iteration 1096: Cost [[0.28204635]]
# Iteration 1097: Cost [[0.2819221]]
# Iteration 1098: Cost [[0.28179801]]
# Iteration 1099: Cost [[0.28167408]]
# Iteration 1100: Cost [[0.28155031]]
# Iteration 1101: Cost [[0.28142669]]
# Iteration 1102: Cost [[0.28130323]]
# Iteration 1103: Cost [[0.28117992]]
# Iteration 1104: Cost [[0.28105677]]
# Iteration 1105: Cost [[0.28093377]]
# Iteration 1106: Cost [[0.28081093]]
# Iteration 1107: Cost [[0.28068824]]
# Iteration 1108: Cost [[0.28056571]]
# Iteration 1109: Cost [[0.28044333]]
# Iteration 1110: Cost [[0.2803211]]
# Iteration 1111: Cost [[0.28019903]]
# Iteration 1112: Cost [[0.28007711]]
# Iteration 1113: Cost [[0.27995535]]
# Iteration 1114: Cost [[0.27983374]]
# Iteration 1115: Cost [[0.27971227]]
# Iteration 1116: Cost [[0.27959097]]
# Iteration 1117: Cost [[0.27946981]]
# Iteration 1118: Cost [[0.2793488]]
# Iteration 1119: Cost [[0.27922795]]
# Iteration 1120: Cost [[0.27910724]]
# Iteration 1121: Cost [[0.27898669]]
# Iteration 1122: Cost [[0.27886629]]
# Iteration 1123: Cost [[0.27874604]]
# Iteration 1124: Cost [[0.27862593]]
# Iteration 1125: Cost [[0.27850598]]
# Iteration 1126: Cost [[0.27838618]]
# Iteration 1127: Cost [[0.27826652]]
# Iteration 1128: Cost [[0.27814701]]
# Iteration 1129: Cost [[0.27802766]]
# Iteration 1130: Cost [[0.27790845]]
# Iteration 1131: Cost [[0.27778938]]
# Iteration 1132: Cost [[0.27767047]]
# Iteration 1133: Cost [[0.2775517]]
# Iteration 1134: Cost [[0.27743308]]
# Iteration 1135: Cost [[0.27731461]]
# Iteration 1136: Cost [[0.27719628]]
# Iteration 1137: Cost [[0.2770781]]
# Iteration 1138: Cost [[0.27696007]]
# Iteration 1139: Cost [[0.27684218]]
# Iteration 1140: Cost [[0.27672444]]
# Iteration 1141: Cost [[0.27660684]]
# Iteration 1142: Cost [[0.27648939]]
# Iteration 1143: Cost [[0.27637208]]
# Iteration 1144: Cost [[0.27625492]]
# Iteration 1145: Cost [[0.2761379]]
# Iteration 1146: Cost [[0.27602102]]
# Iteration 1147: Cost [[0.27590429]]
# Iteration 1148: Cost [[0.2757877]]
# Iteration 1149: Cost [[0.27567126]]
# Iteration 1150: Cost [[0.27555496]]
# Iteration 1151: Cost [[0.2754388]]
# Iteration 1152: Cost [[0.27532278]]
# Iteration 1153: Cost [[0.27520691]]
# Iteration 1154: Cost [[0.27509117]]
# Iteration 1155: Cost [[0.27497558]]
# Iteration 1156: Cost [[0.27486013]]
# Iteration 1157: Cost [[0.27474482]]
# Iteration 1158: Cost [[0.27462966]]
# Iteration 1159: Cost [[0.27451463]]
# Iteration 1160: Cost [[0.27439974]]
# Iteration 1161: Cost [[0.274285]]
# Iteration 1162: Cost [[0.27417039]]
# Iteration 1163: Cost [[0.27405592]]
# Iteration 1164: Cost [[0.27394159]]
# Iteration 1165: Cost [[0.27382741]]
# Iteration 1166: Cost [[0.27371336]]
# Iteration 1167: Cost [[0.27359944]]
# Iteration 1168: Cost [[0.27348567]]
# Iteration 1169: Cost [[0.27337204]]
# Iteration 1170: Cost [[0.27325854]]
# Iteration 1171: Cost [[0.27314518]]
# Iteration 1172: Cost [[0.27303196]]
# Iteration 1173: Cost [[0.27291888]]
# Iteration 1174: Cost [[0.27280593]]
# Iteration 1175: Cost [[0.27269312]]
# Iteration 1176: Cost [[0.27258044]]
# Iteration 1177: Cost [[0.2724679]]
# Iteration 1178: Cost [[0.2723555]]
# Iteration 1179: Cost [[0.27224324]]
# Iteration 1180: Cost [[0.2721311]]
# Iteration 1181: Cost [[0.27201911]]
# Iteration 1182: Cost [[0.27190725]]
# Iteration 1183: Cost [[0.27179552]]
# Iteration 1184: Cost [[0.27168393]]
# Iteration 1185: Cost [[0.27157247]]
# Iteration 1186: Cost [[0.27146115]]
# Iteration 1187: Cost [[0.27134996]]
# Iteration 1188: Cost [[0.27123891]]
# Iteration 1189: Cost [[0.27112798]]
# Iteration 1190: Cost [[0.27101719]]
# Iteration 1191: Cost [[0.27090654]]
# Iteration 1192: Cost [[0.27079601]]
# Iteration 1193: Cost [[0.27068562]]
# Iteration 1194: Cost [[0.27057536]]
# Iteration 1195: Cost [[0.27046524]]
# Iteration 1196: Cost [[0.27035524]]
# Iteration 1197: Cost [[0.27024538]]
# Iteration 1198: Cost [[0.27013564]]
# Iteration 1199: Cost [[0.27002604]]
# Iteration 1200: Cost [[0.26991657]]
# Iteration 1201: Cost [[0.26980723]]
# Iteration 1202: Cost [[0.26969802]]
# Iteration 1203: Cost [[0.26958894]]
# Iteration 1204: Cost [[0.26947999]]
# Iteration 1205: Cost [[0.26937117]]
# Iteration 1206: Cost [[0.26926248]]
# Iteration 1207: Cost [[0.26915392]]
# Iteration 1208: Cost [[0.26904548]]
# Iteration 1209: Cost [[0.26893718]]
# Iteration 1210: Cost [[0.268829]]
# Iteration 1211: Cost [[0.26872096]]
# Iteration 1212: Cost [[0.26861304]]
# Iteration 1213: Cost [[0.26850525]]
# Iteration 1214: Cost [[0.26839758]]
# Iteration 1215: Cost [[0.26829005]]
# Iteration 1216: Cost [[0.26818264]]
# Iteration 1217: Cost [[0.26807535]]
# Iteration 1218: Cost [[0.2679682]]
# Iteration 1219: Cost [[0.26786117]]
# Iteration 1220: Cost [[0.26775427]]
# Iteration 1221: Cost [[0.26764749]]
# Iteration 1222: Cost [[0.26754084]]
# Iteration 1223: Cost [[0.26743432]]
# Iteration 1224: Cost [[0.26732792]]
# Iteration 1225: Cost [[0.26722164]]
# Iteration 1226: Cost [[0.26711549]]
# Iteration 1227: Cost [[0.26700947]]
# Iteration 1228: Cost [[0.26690357]]
# Iteration 1229: Cost [[0.26679779]]
# Iteration 1230: Cost [[0.26669214]]
# Iteration 1231: Cost [[0.26658662]]
# Iteration 1232: Cost [[0.26648121]]
# Iteration 1233: Cost [[0.26637593]]
# Iteration 1234: Cost [[0.26627078]]
# Iteration 1235: Cost [[0.26616574]]
# Iteration 1236: Cost [[0.26606083]]
# Iteration 1237: Cost [[0.26595604]]
# Iteration 1238: Cost [[0.26585138]]
# Iteration 1239: Cost [[0.26574684]]
# Iteration 1240: Cost [[0.26564241]]
# Iteration 1241: Cost [[0.26553811]]
# Iteration 1242: Cost [[0.26543394]]
# Iteration 1243: Cost [[0.26532988]]
# Iteration 1244: Cost [[0.26522595]]
# Iteration 1245: Cost [[0.26512213]]
# Iteration 1246: Cost [[0.26501844]]
# Iteration 1247: Cost [[0.26491487]]
# Iteration 1248: Cost [[0.26481141]]
# Iteration 1249: Cost [[0.26470808]]
# Iteration 1250: Cost [[0.26460487]]
# Iteration 1251: Cost [[0.26450178]]
# Iteration 1252: Cost [[0.2643988]]
# Iteration 1253: Cost [[0.26429595]]
# Iteration 1254: Cost [[0.26419322]]
# Iteration 1255: Cost [[0.2640906]]
# Iteration 1256: Cost [[0.2639881]]
# Iteration 1257: Cost [[0.26388573]]
# Iteration 1258: Cost [[0.26378347]]
# Iteration 1259: Cost [[0.26368132]]
# Iteration 1260: Cost [[0.2635793]]
# Iteration 1261: Cost [[0.26347739]]
# Iteration 1262: Cost [[0.26337561]]
# Iteration 1263: Cost [[0.26327394]]
# Iteration 1264: Cost [[0.26317238]]
# Iteration 1265: Cost [[0.26307094]]
# Iteration 1266: Cost [[0.26296962]]
# Iteration 1267: Cost [[0.26286842]]
# Iteration 1268: Cost [[0.26276733]]
# Iteration 1269: Cost [[0.26266636]]
# Iteration 1270: Cost [[0.26256551]]
# Iteration 1271: Cost [[0.26246477]]
# Iteration 1272: Cost [[0.26236415]]
# Iteration 1273: Cost [[0.26226364]]
# Iteration 1274: Cost [[0.26216324]]
# Iteration 1275: Cost [[0.26206297]]
# Iteration 1276: Cost [[0.2619628]]
# Iteration 1277: Cost [[0.26186275]]
# Iteration 1278: Cost [[0.26176282]]
# Iteration 1279: Cost [[0.261663]]
# Iteration 1280: Cost [[0.26156329]]
# Iteration 1281: Cost [[0.2614637]]
# Iteration 1282: Cost [[0.26136422]]
# Iteration 1283: Cost [[0.26126486]]
# Iteration 1284: Cost [[0.26116561]]
# Iteration 1285: Cost [[0.26106647]]
# Iteration 1286: Cost [[0.26096744]]
# Iteration 1287: Cost [[0.26086853]]
# Iteration 1288: Cost [[0.26076973]]
# Iteration 1289: Cost [[0.26067104]]
# Iteration 1290: Cost [[0.26057247]]
# Iteration 1291: Cost [[0.260474]]
# Iteration 1292: Cost [[0.26037565]]
# Iteration 1293: Cost [[0.26027741]]
# Iteration 1294: Cost [[0.26017928]]
# Iteration 1295: Cost [[0.26008126]]
# Iteration 1296: Cost [[0.25998336]]
# Iteration 1297: Cost [[0.25988556]]
# Iteration 1298: Cost [[0.25978787]]
# Iteration 1299: Cost [[0.2596903]]
# Iteration 1300: Cost [[0.25959283]]
# Iteration 1301: Cost [[0.25949548]]
# Iteration 1302: Cost [[0.25939823]]
# Iteration 1303: Cost [[0.2593011]]
# Iteration 1304: Cost [[0.25920407]]
# Iteration 1305: Cost [[0.25910716]]
# Iteration 1306: Cost [[0.25901035]]
# Iteration 1307: Cost [[0.25891365]]
# Iteration 1308: Cost [[0.25881707]]
# Iteration 1309: Cost [[0.25872058]]
# Iteration 1310: Cost [[0.25862421]]
# Iteration 1311: Cost [[0.25852795]]
# Iteration 1312: Cost [[0.25843179]]
# Iteration 1313: Cost [[0.25833575]]
# Iteration 1314: Cost [[0.25823981]]
# Iteration 1315: Cost [[0.25814398]]
# Iteration 1316: Cost [[0.25804825]]
# Iteration 1317: Cost [[0.25795263]]
# Iteration 1318: Cost [[0.25785712]]
# Iteration 1319: Cost [[0.25776172]]
# Iteration 1320: Cost [[0.25766642]]
# Iteration 1321: Cost [[0.25757123]]
# Iteration 1322: Cost [[0.25747615]]
# Iteration 1323: Cost [[0.25738117]]
# Iteration 1324: Cost [[0.2572863]]
# Iteration 1325: Cost [[0.25719153]]
# Iteration 1326: Cost [[0.25709687]]
# Iteration 1327: Cost [[0.25700232]]
# Iteration 1328: Cost [[0.25690787]]
# Iteration 1329: Cost [[0.25681353]]
# Iteration 1330: Cost [[0.25671929]]
# Iteration 1331: Cost [[0.25662515]]
# Iteration 1332: Cost [[0.25653112]]
# Iteration 1333: Cost [[0.2564372]]
# Iteration 1334: Cost [[0.25634338]]
# Iteration 1335: Cost [[0.25624966]]
# Iteration 1336: Cost [[0.25615605]]
# Iteration 1337: Cost [[0.25606254]]
# Iteration 1338: Cost [[0.25596913]]
# Iteration 1339: Cost [[0.25587583]]
# Iteration 1340: Cost [[0.25578263]]
# Iteration 1341: Cost [[0.25568953]]
# Iteration 1342: Cost [[0.25559654]]
# Iteration 1343: Cost [[0.25550365]]
# Iteration 1344: Cost [[0.25541086]]
# Iteration 1345: Cost [[0.25531818]]
# Iteration 1346: Cost [[0.25522559]]
# Iteration 1347: Cost [[0.25513311]]
# Iteration 1348: Cost [[0.25504074]]
# Iteration 1349: Cost [[0.25494846]]
# Iteration 1350: Cost [[0.25485628]]
# Iteration 1351: Cost [[0.25476421]]
# Iteration 1352: Cost [[0.25467224]]
# Iteration 1353: Cost [[0.25458036]]
# Iteration 1354: Cost [[0.25448859]]
# Iteration 1355: Cost [[0.25439692]]
# Iteration 1356: Cost [[0.25430535]]
# Iteration 1357: Cost [[0.25421389]]
# Iteration 1358: Cost [[0.25412252]]
# Iteration 1359: Cost [[0.25403125]]
# Iteration 1360: Cost [[0.25394008]]
# Iteration 1361: Cost [[0.25384901]]
# Iteration 1362: Cost [[0.25375804]]
# Iteration 1363: Cost [[0.25366717]]
# Iteration 1364: Cost [[0.2535764]]
# Iteration 1365: Cost [[0.25348573]]
# Iteration 1366: Cost [[0.25339516]]
# Iteration 1367: Cost [[0.25330469]]
# Iteration 1368: Cost [[0.25321431]]
# Iteration 1369: Cost [[0.25312404]]
# Iteration 1370: Cost [[0.25303386]]
# Iteration 1371: Cost [[0.25294378]]
# Iteration 1372: Cost [[0.2528538]]
# Iteration 1373: Cost [[0.25276392]]
# Iteration 1374: Cost [[0.25267413]]
# Iteration 1375: Cost [[0.25258444]]
# Iteration 1376: Cost [[0.25249485]]
# Iteration 1377: Cost [[0.25240536]]
# Iteration 1378: Cost [[0.25231596]]
# Iteration 1379: Cost [[0.25222666]]
# Iteration 1380: Cost [[0.25213746]]
# Iteration 1381: Cost [[0.25204836]]
# Iteration 1382: Cost [[0.25195935]]
# Iteration 1383: Cost [[0.25187043]]
# Iteration 1384: Cost [[0.25178162]]
# Iteration 1385: Cost [[0.2516929]]
# Iteration 1386: Cost [[0.25160427]]
# Iteration 1387: Cost [[0.25151574]]
# Iteration 1388: Cost [[0.25142731]]
# Iteration 1389: Cost [[0.25133897]]
# Iteration 1390: Cost [[0.25125073]]
# Iteration 1391: Cost [[0.25116258]]
# Iteration 1392: Cost [[0.25107453]]
# Iteration 1393: Cost [[0.25098657]]
# Iteration 1394: Cost [[0.25089871]]
# Iteration 1395: Cost [[0.25081094]]
# Iteration 1396: Cost [[0.25072327]]
# Iteration 1397: Cost [[0.25063569]]
# Iteration 1398: Cost [[0.2505482]]
# Iteration 1399: Cost [[0.25046081]]
# Iteration 1400: Cost [[0.25037351]]
# Iteration 1401: Cost [[0.25028631]]
# Iteration 1402: Cost [[0.2501992]]
# Iteration 1403: Cost [[0.25011218]]
# Iteration 1404: Cost [[0.25002525]]
# Iteration 1405: Cost [[0.24993842]]
# Iteration 1406: Cost [[0.24985168]]
# Iteration 1407: Cost [[0.24976504]]
# Iteration 1408: Cost [[0.24967849]]
# Iteration 1409: Cost [[0.24959202]]
# Iteration 1410: Cost [[0.24950566]]
# Iteration 1411: Cost [[0.24941938]]
# Iteration 1412: Cost [[0.2493332]]
# Iteration 1413: Cost [[0.2492471]]
# Iteration 1414: Cost [[0.2491611]]
# Iteration 1415: Cost [[0.24907519]]
# Iteration 1416: Cost [[0.24898938]]
# Iteration 1417: Cost [[0.24890365]]
# Iteration 1418: Cost [[0.24881802]]
# Iteration 1419: Cost [[0.24873247]]
# Iteration 1420: Cost [[0.24864702]]
# Iteration 1421: Cost [[0.24856166]]
# Iteration 1422: Cost [[0.24847638]]
# Iteration 1423: Cost [[0.2483912]]
# Iteration 1424: Cost [[0.24830611]]
# Iteration 1425: Cost [[0.24822111]]
# Iteration 1426: Cost [[0.2481362]]
# Iteration 1427: Cost [[0.24805138]]
# Iteration 1428: Cost [[0.24796665]]
# Iteration 1429: Cost [[0.24788201]]
# Iteration 1430: Cost [[0.24779746]]
# Iteration 1431: Cost [[0.24771299]]
# Iteration 1432: Cost [[0.24762862]]
# Iteration 1433: Cost [[0.24754433]]
# Iteration 1434: Cost [[0.24746014]]
# Iteration 1435: Cost [[0.24737603]]
# Iteration 1436: Cost [[0.24729201]]
# Iteration 1437: Cost [[0.24720808]]
# Iteration 1438: Cost [[0.24712424]]
# Iteration 1439: Cost [[0.24704049]]
# Iteration 1440: Cost [[0.24695682]]
# Iteration 1441: Cost [[0.24687325]]
# Iteration 1442: Cost [[0.24678976]]
# Iteration 1443: Cost [[0.24670636]]
# Iteration 1444: Cost [[0.24662304]]
# Iteration 1445: Cost [[0.24653982]]
# Iteration 1446: Cost [[0.24645668]]
# Iteration 1447: Cost [[0.24637362]]
# Iteration 1448: Cost [[0.24629066]]
# Iteration 1449: Cost [[0.24620778]]
# Iteration 1450: Cost [[0.24612499]]
# Iteration 1451: Cost [[0.24604228]]
# Iteration 1452: Cost [[0.24595967]]
# Iteration 1453: Cost [[0.24587713]]
# Iteration 1454: Cost [[0.24579469]]
# Iteration 1455: Cost [[0.24571233]]
# Iteration 1456: Cost [[0.24563005]]
# Iteration 1457: Cost [[0.24554786]]
# Iteration 1458: Cost [[0.24546576]]
# Iteration 1459: Cost [[0.24538374]]
# Iteration 1460: Cost [[0.24530181]]
# Iteration 1461: Cost [[0.24521997]]
# Iteration 1462: Cost [[0.24513821]]
# Iteration 1463: Cost [[0.24505653]]
# Iteration 1464: Cost [[0.24497494]]
# Iteration 1465: Cost [[0.24489343]]
# Iteration 1466: Cost [[0.24481201]]
# Iteration 1467: Cost [[0.24473067]]
# Iteration 1468: Cost [[0.24464942]]
# Iteration 1469: Cost [[0.24456825]]
# Iteration 1470: Cost [[0.24448716]]
# Iteration 1471: Cost [[0.24440616]]
# Iteration 1472: Cost [[0.24432525]]
# Iteration 1473: Cost [[0.24424441]]
# Iteration 1474: Cost [[0.24416366]]
# Iteration 1475: Cost [[0.244083]]
# Iteration 1476: Cost [[0.24400241]]
# Iteration 1477: Cost [[0.24392191]]
# Iteration 1478: Cost [[0.2438415]]
# Iteration 1479: Cost [[0.24376116]]
# Iteration 1480: Cost [[0.24368091]]
# Iteration 1481: Cost [[0.24360075]]
# Iteration 1482: Cost [[0.24352066]]
# Iteration 1483: Cost [[0.24344066]]
# Iteration 1484: Cost [[0.24336074]]
# Iteration 1485: Cost [[0.2432809]]
# Iteration 1486: Cost [[0.24320114]]
# Iteration 1487: Cost [[0.24312147]]
# Iteration 1488: Cost [[0.24304187]]
# Iteration 1489: Cost [[0.24296236]]
# Iteration 1490: Cost [[0.24288293]]
# Iteration 1491: Cost [[0.24280359]]
# Iteration 1492: Cost [[0.24272432]]
# Iteration 1493: Cost [[0.24264513]]
# Iteration 1494: Cost [[0.24256603]]
# Iteration 1495: Cost [[0.24248701]]
# Iteration 1496: Cost [[0.24240806]]
# Iteration 1497: Cost [[0.2423292]]
# Iteration 1498: Cost [[0.24225042]]
# Iteration 1499: Cost [[0.24217172]]
# The cost after training is 0.24217172.
# The resulting vector of weights is [7e-08, 0.00052352, -0.00055579]
# C:\Users\User\AppData\Local\Temp\ipykernel_9224\3262105165.py:35: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   J = float(J)

# %% [markdown]
# **Expected Output**:
#
# ```
# The cost after training is 0.24216529.
# The resulting vector of weights is [7e-08, 0.0005239, -0.00055517]
# ```

# %% [markdown]
# # Part 4: Test your logistic regression
#
# It is time for you to test your logistic regression function on some new input that your model has not seen before.
#
# #### Instructions: Write `predict_tweet`
# Predict whether a tweet is positive or negative.
#
# * Given a tweet, process it, then extract the features.
# * Apply the model's learned weights on the features to get the logits.
# * Apply the sigmoid to the logits to get the prediction (a value between 0 and 1).
#
# $$y_{pred} = sigmoid(\mathbf{x} \cdot \theta)$$

# %%
# UNQ_C4 (UNIQUE CELL IDENTIFIER, DO NOT EDIT)
def predict_tweet(tweet, freqs, theta):
    '''
    Input: 
        tweet: a string
        freqs: a dictionary corresponding to the frequencies of each tuple (word, label)
        theta: (3,1) vector of weights
    Output: 
        y_pred: the probability of a tweet being positive or negative
    '''
    ### START CODE HERE (REPLACE INSTANCES OF 'None' with your code) ###
    
    # extract the features of the tweet and store it into x
    x = extract_features(tweet, freqs)
    
    # make the prediction using x and theta
    y_pred = sigmoid(np.dot(x, theta))
    
    ### END CODE HERE ###
    
    return y_pred

# %%
# Run this cell to test your function
for tweet in ['I am happy', 'I am bad', 'this movie should have been great.', 'great', 'great great', 'great great great', 'great great great great']:
    print( '%s -> %f' % (tweet, predict_tweet(tweet, freqs, theta)))
# Out:
# I am happy -> 0.518562
# I am bad -> 0.494329
# this movie should have been great. -> 0.515312
# great -> 0.515449
# great great -> 0.530868
# great great great -> 0.546228
# great great great great -> 0.561501
# C:\Users\User\AppData\Local\Temp\ipykernel_9224\2209103747.py:3: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   print( '%s -> %f' % (tweet, predict_tweet(tweet, freqs, theta)))

# %% [markdown]
# **Expected Output**:
# ```
# I am happy -> 0.518580
# I am bad -> 0.494339
# this movie should have been great. -> 0.515331
# great -> 0.515464
# great great -> 0.530898
# great great great -> 0.546273
# great great great great -> 0.561561
# ```

# %%
# Feel free to check the sentiment of your own tweet below
my_tweet = 'I am learning :)'
predict_tweet(my_tweet, freqs, theta)
# Out:
# array([[0.81620065]])

# %% [markdown]
# ## Check performance using the test set
# After training your model using the training set above, check how your model might perform on real, unseen data, by testing it against the test set.
#
# #### Instructions: Implement `test_logistic_regression`
# * Given the test data and the weights of your trained model, calculate the accuracy of your logistic regression model.
# * Use your `predict_tweet()` function to make predictions on each tweet in the test set.
# * If the prediction is > 0.5, set the model's classification `y_hat` to 1, otherwise set the model's classification `y_hat` to 0.
# * A prediction is accurate when `y_hat` equals `test_y`.  Sum up all the instances when they are equal and divide by `m`.

# %% [markdown]
# <details>
# <summary>
#     <font size="3" color="darkgreen"><b>Hints</b></font>
# </summary>
# <p>
# <ul>
#     <li>Use np.asarray() to convert a list to a numpy array</li>
#     <li>Use np.squeeze() to make an (m,1) dimensional array into an (m,) array </li>
# </ul>
# </p>

# %%
# UNQ_C5 (UNIQUE CELL IDENTIFIER, DO NOT EDIT)
def test_logistic_regression(test_x, test_y, freqs, theta):
    """
    Input: 
        test_x: a list of tweets
        test_y: (m, 1) vector with the corresponding labels for the list of tweets
        freqs: a dictionary with the frequency of each pair (or tuple)
        theta: weight vector of dimension (3, 1)
    Output: 
        accuracy: (# of tweets classified correctly) / (total # of tweets)
    """
    
    ### START CODE HERE (REPLACE INSTANCES OF 'None' with your code) ###
    
    # the list for storing predictions
    y_hat = []
    
    for tweet in test_x:
        # get the label prediction for the tweet
        y_pred = predict_tweet(tweet, freqs, theta)
        
        if y_pred > 0.5:
            # append 1.0 to the list
            y_hat.append(1.0)
        else:
            # append 0 to the list
            y_hat.append(0.0)

    # With the above implementation, y_hat is a list, but test_y is (m,1) array
    # convert both to one-dimensional arrays in order to compare them using the '==' operator
    y_hat = np.array(y_hat)
    test_y = test_y.flatten()
    accuracy = np.mean(y_hat == test_y)

    ### END CODE HERE ###
    
    return accuracy

# %%
tmp_accuracy = test_logistic_regression(test_x, test_y, freqs, theta)
print(f"Logistic regression model's accuracy = {tmp_accuracy:.4f}")
# Out:
# Logistic regression model's accuracy = 0.9965

# %% [markdown]
# #### Expected Output:
# ```0.9950```
# Pretty good!

# %% [markdown]
# # Part 5: Error Analysis
#
# In this part you will see some tweets that your model misclassified. Why do you think the misclassifications happened? Specifically what kind of tweets does your model misclassify?

# %%
# Some error analysis done for you
print('Label Predicted Tweet')
for x,y in zip(test_x,test_y):
    y_hat = predict_tweet(x, freqs, theta)

    if np.abs(y - (y_hat > 0.5)) > 0:
        print('THE TWEET IS:', x)
        print('THE PROCESSED TWEET IS:', process_tweet(x))
        print('%d\t%0.8f\t%s' % (y, y_hat, ' '.join(process_tweet(x)).encode('ascii', 'ignore')))
# Out:
# Label Predicted Tweet
# THE TWEET IS: @jaredNOTsubway @iluvmariah @Bravotv Then that truly is a LATERAL move! Now, we all know the Queen Bee is UPWARD BOUND : ) #MovingOnUp
# THE PROCESSED TWEET IS: ['truli', 'later', 'move', 'know', 'queen', 'bee', 'upward', 'bound', 'movingonup']
# 1	0.49993350	b'truli later move know queen bee upward bound movingonup'
# C:\Users\User\AppData\Local\Temp\ipykernel_9224\289099189.py:9: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   print('%d\t%0.8f\t%s' % (y, y_hat, ' '.join(process_tweet(x)).encode('ascii', 'ignore')))
# THE TWEET IS: @MarkBreech Not sure it would be good thing 4 my bottom daring 2 say 2 Miss B but Im gonna be so stubborn on mouth soaping ! #NotHavingit :p
# THE PROCESSED TWEET IS: ['sure', 'would', 'good', 'thing', '4', 'bottom', 'dare', '2', 'say', '2', 'miss', 'b', 'im', 'gonna', 'stubborn', 'mouth', 'soap', 'nothavingit', ':p']
# 1	0.48645722	b'sure would good thing 4 bottom dare 2 say 2 miss b im gonna stubborn mouth soap nothavingit :p'
# THE TWEET IS: off to the park to get some sunlight : )
# THE PROCESSED TWEET IS: ['park', 'get', 'sunlight']
# 1	0.49574271	b'park get sunlight'
# THE TWEET IS: @msarosh Uff Itna Miss karhy thy ap :p
# THE PROCESSED TWEET IS: ['uff', 'itna', 'miss', 'karhi', 'thi', 'ap', ':p']
# 1	0.48207960	b'uff itna miss karhi thi ap :p'
# THE TWEET IS: @phenomyoutube u probs had more fun with david than me : (
# THE PROCESSED TWEET IS: ['u', 'prob', 'fun', 'david']
# 0	0.50015845	b'u prob fun david'
# THE TWEET IS: pats jay : (
# THE PROCESSED TWEET IS: ['pat', 'jay']
# 0	0.50039266	b'pat jay'
# THE TWEET IS: my beloved grandmother : ( https://t.co/wt4oXq5xCf
# THE PROCESSED TWEET IS: ['belov', 'grandmoth']
# 0	0.50000002	b'belov grandmoth'

# %% [markdown]
# Later in this specialization, we will see how we can use deep learning to improve the prediction performance.

# %% [markdown]
# # Part 6: Predict with your own tweet

# %%
# Feel free to change the tweet below
my_tweet = 'This is a ridiculously bright movie. The plot was terrible and I was sad until the ending!'
print(process_tweet(my_tweet))
y_hat = predict_tweet(my_tweet, freqs, theta)
print(y_hat)
if y_hat > 0.5:
    print('Positive sentiment')
else: 
    print('Negative sentiment')
# Out:
# ['ridicul', 'bright', 'movi', 'plot', 'terribl', 'sad', 'end']
# [[0.48136082]]
# Negative sentiment
